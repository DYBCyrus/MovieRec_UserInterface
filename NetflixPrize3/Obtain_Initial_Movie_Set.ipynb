# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import random
import json
import math

# %%
imdb_df = pd.read_csv('IMDB_Final_Movies.csv')
imdb_df.head()
# Out:
#       tconst                    primaryTitle                   originalTitle  \
# 0  tt0000009                      Miss Jerry                      Miss Jerry
# 1  tt0000630                          Hamlet                          Amleto
# 2  tt0000679  The Fairylogue and Radio-Plays  The Fairylogue and Radio-Plays
# 3  tt0000886       Hamlet, Prince of Denmark                          Hamlet
# 4  tt0001482           As in a Looking Glass           As in a Looking Glass
#
#                 titles from US/UK  startYear region             genres  \
# 0                      Miss Jerry     1894.0     US            Romance
# 1                          Hamlet     1908.0     US              Drama
# 2  The Fairylogue and Radio-Plays     1908.0     US  Adventure,Fantasy
# 3       Hamlet, Prince of Denmark     1910.0     US              Drama
# 4           As in a Looking Glass     1911.0     US              Drama
#
#              directors_names              writers_names  \
# 0            Alexander Black            Alexander Black
# 1             Mario Caserini        William Shakespeare
# 2  Francis Boggs/Otis Turner  L. Frank Baum/Otis Turner
# 3           Gérard Bourgeois        William Shakespeare
# 4              D.W. Griffith            George Hennessy
#
#                                            cast_name  averageRating  numVotes
# 0                  Blanche Bayliss/William Courtenay            5.5        78
# 1                              Fernanda Negri Pouget            2.9        11
# 2  Evelyn Judson/Sam 'Smiling' Jones/Annabel Jeph...            4.8        33
# 3                                  Jean Mounet-Sully            5.1        19
# 4  Wilfred Lucas/George Hennessy/Claire McDowell/...            5.1        26

# %%
print(imdb_df.shape)
imdb_df.dropna(inplace=True)
print(imdb_df.shape)
# Out:
# (79211, 12)
# (79211, 12)

# %%
imdb_df.to_csv("IMDB_Final_Movies.csv", index=False)

# %%
genre_to_movie_rating_pair = defaultdict(list)
for i in range(imdb_df.shape[0]):
    title = imdb_df.iloc[i]['primaryTitle']
    year = str(int(imdb_df.iloc[i]['startYear']))
    genres = imdb_df.iloc[i]['genres'].split(',')
    rate = float(imdb_df.iloc[i]['averageRating'])
    numVotes = int(imdb_df.iloc[i]['numVotes'])
    for g in genres:
        genre_to_movie_rating_pair[g].append((title,year,rate,numVotes))

# %%
genre_to_movie_rating_pair['Drama']
# Out:
# [('Hamlet', '1908', 2.9, 11),
#  ('Hamlet, Prince of Denmark', '1910', 5.1, 19),
#  ('As in a Looking Glass', '1911', 5.1, 26),
#  ('Nell Gwynne', '1911', 4.2, 8),
#  ('Cleopatra', '1912', 5.1, 385),
#  ("Dante's Inferno", '1911', 7.1, 1846),
#  ('The Great Circus Catastrophe', '1912', 5.7, 39),
#  ('The Flying Circus', '1912', 6.4, 69),
#  ('From the Manger to the Cross; or, Jesus of Nazareth', '1912', 5.8, 421),
#  ('Madame DuBarry', '1919', 6.9, 680),
#  ('Saved in Mid-Air', '1912', 5.8, 8),
#  ('The Battle of Gettysburg', '1913', 6.2, 20),
#  ('Caprice', '1913', 6.1, 9),
#  ('The Count of Monte Cristo', '1913', 5.4, 35),
#  ('What 80 Million Women Want', '1913', 4.3, 26),
#  ('Fantômas: In the Shadow of the Guillotine', '1913', 6.9, 1806),
#  ('From Dusk to Dawn', '1913', 5.9, 87),
#  ('Germinal; or, The Toll of Labor', '1913', 6.9, 82),
#  ('Ivanhoe', '1913', 5.4, 39),
#  ('Love Everlasting', '1914', 6.5, 84),
#  ('War Is Hell', '1914', 6.9, 93),
#  ('Fantômas: The Dead Man Who Killed', '1913', 6.9, 974),
#  ('One Hundred Years of Mormonism', '1913', 4.7, 9),
#  ('The Life of Richard Wagner', '1913', 6.3, 79),
#  ('The Sea Wolf', '1913', 5.2, 11),
#  ('Shadows of the Moulin Rouge', '1913', 5.3, 6),
#  ('The Student of Prague', '1913', 6.6, 1557),
#  ('Ten Nights in a Barroom', '1913', 5.8, 20),
#  ("Tess of the D'Urbervilles", '1913', 5.2, 9),
#  ('Traffic in Souls', '1913', 6.1, 511),
#  ('The Last Days of Pompeii', '1913', 6.1, 446),
#  ('Across the Pacific', '1914', 4.1, 10),
#  ('The Active Life of Dolly of the Dailies', '1914', 6.2, 40),
#  ('Assunta Spina', '1915', 6.5, 349),
#  ("Burning Daylight: The Adventures of 'Burning Daylight' in Alaska",
#   '1914',
#   4.8,
#   9),
#  ('The Call of the North', '1914', 5.5, 23),
#  ('Cinderella', '1914', 6.6, 898),
#  ('The Dream Woman', '1914', 5.4, 8),
#  ('The Escape', '1914', 6.1, 15),
#  ('Fantomas: The Mysterious Finger Print', '1914', 6.8, 1086),
#  ('Fantômas: The False Magistrate', '1914', 6.9, 865),
#  ('Julius Caesar', '1914', 6.4, 34),
#  ('A Good Little Devil', '1914', 5.8, 11),
#  ('Sealed Orders', '1914', 7.1, 441),
#  ('The House Next Door', '1914', 3.8, 5),
#  ('Hypocrites', '1915', 6.6, 415),
#  ('In the Land of the Head Hunters', '1914', 6.0, 364),
#  ('Jane Eyre', '1914', 6.4, 8),
#  ('Joseph in the Land of Egypt', '1914', 5.1, 19),
#  ('Judith of Bethulia', '1914', 7.2, 1157),
#  ('The Jungle', '1914', 7.2, 42),
#  ('The Last Egyptian', '1914', 5.2, 9),
#  ('Lola', '1914', 4.9, 8),
#  ('Martin Eden', '1914', 5.9, 7),
#  ('The Master Key', '1914', 4.9, 10),
#  ('McVeagh of the South Seas', '1914', 4.6, 11),
#  ('The Merchant of Venice', '1914', 5.5, 13),
#  ('Michael Strogoff', '1914', 5.5, 14),
#  ('My Official Wife', '1914', 6.1, 17),
#  ('The Naked Truth', '1914', 4.5, 10),
#  ('Down with Weapons', '1914', 5.6, 17),
#  ('Mute Witnesses', '1914', 6.1, 70),
#  ('The Nightingale', '1914', 7.2, 12),
#  ('The Perils of Pauline', '1914', 7.5, 911),
#  ('The Reign of Terror', '1914', 5.8, 28),
#  ('Samson', '1914', 4.6, 9),
#  ('The Sign of the Cross', '1914', 6.3, 27),
#  ('The Spoilers', '1914', 6.6, 43),
#  ('The Squaw Man', '1914', 6.1, 783),
#  ('Tess of the Storm Country', '1914', 6.3, 146),
#  ('The Undesirable', '1915', 6.2, 147),
#  ("Uncle Tom's Cabin", '1914', 5.4, 89),
#  ("What's His Name", '1914', 6.2, 10),
#  ('The Wishing Ring: An Idyll of Old England', '1914', 6.6, 206),
#  ('Alias Jimmy Valentine', '1915', 6.2, 192),
#  ('Anna Karenina', '1915', 4.2, 5),
#  ('The Battle Cry of Peace', '1915', 4.4, 8),
#  ('Betty in Search of a Thrill', '1915', 6.4, 8),
#  ('The Birth of a Nation', '1915', 6.6, 20253),
#  ('The Black Box', '1915', 3.6, 8),
#  ('The Builder of Bridges', '1915', 7.6, 5),
#  ('Camille', '1915', 6.2, 6),
#  ("Cap'n Eri", '1915', 8.4, 14),
#  ('The Captive', '1915', 6.4, 66),
#  ('Carmen', '1915', 6.9, 832),
#  ('Carmen', '1915', 5.0, 16),
#  ('The Cheat', '1915', 6.6, 2151),
#  ('Children of Eve', '1915', 6.6, 65),
#  ('The Coward', '1915', 6.1, 200),
#  ('The Cub', '1915', 6.6, 11),
#  ('The Darkening Trail', '1915', 6.1, 13),
#  ('David Harum', '1915', 5.7, 20),
#  ('The Dawn of a Tomorrow', '1915', 7.0, 15),
#  ('Destruction', '1915', 7.8, 10),
#  ("The Devil's Daughter", '1915', 6.0, 7),
#  ('The Devil', '1915', 8.2, 5),
#  ('Don Quixote', '1915', 5.7, 9),
#  ('The Eternal City', '1915', 6.7, 6),
#  ('Fanchon, the Cricket', '1915', 6.8, 23),
#  ('A Fool There Was', '1915', 5.9, 703),
#  ('The Foundling', '1915', 5.6, 7),
#  ('Four Feathers', '1915', 7.2, 24),
#  ('From the Valley of the Missing', '1915', 6.9, 9),
#  ('The Gentleman from Indiana', '1915', 6.3, 9),
#  ('Ghosts', '1915', 5.3, 17),
#  ('A Gilded Fool', '1915', 7.8, 17),
#  ('The Golden Chance', '1915', 6.5, 161),
#  ('Blind Justice', '1916', 7.1, 230),
#  ('The Immigrant', '1915', 7.7, 21),
#  ('Inspiration', '1915', 7.7, 16),
#  ("It's No Laughing Matter", '1915', 8.3, 6),
#  ('The Eternal Strife', '1915', 3.9, 13),
#  ('The Juggernaut', '1915', 5.9, 14),
#  ('Kindling', '1915', 6.1, 16),
#  ('Kreutzer Sonata', '1915', 6.4, 8),
#  ('Let Katie Do It', '1916', 6.3, 7),
#  ('Life Without Soul', '1915', 6.9, 23),
#  ('The Lily and the Rose', '1915', 6.9, 36),
#  ('The Lure of the Mask', '1915', 1.0, 7),
#  ('Madame Butterfly', '1915', 5.5, 50),
#  ('Martyrs of the Alamo', '1915', 5.9, 120),
#  ('The Millionaire Baby', '1915', 5.0, 7),
#  ('Mistress Nell', '1915', 7.3, 10),
#  ('Mortmain', '1915', 5.6, 7),
#  ('Old Heidelberg', '1915', 6.8, 20),
#  ('Playing Dead', '1915', 5.1, 7),
#  ('After Death', '1916', 6.9, 725),
#  ('Princess Romanoff', '1915', 5.3, 9),
#  ('The Quest', '1915', 5.1, 16),
#  ('Rags', '1915', 8.6, 17),
#  ("Satan's Rhapsody", '1917', 7.0, 499),
#  ('The Raven', '1915', 5.4, 72),
#  ('The Regeneration', '1915', 6.9, 1017),
#  ('Saved from the Harem', '1915', 7.0, 7),
#  ('Scandal', '1915', 6.5, 13),
#  ('The Stolen Voice', '1915', 7.3, 11),
#  ('Trilby', '1915', 6.1, 75),
#  ('The Valley of Decision', '1916', 7.2, 5),
#  ('Vanity Fair', '1915', 5.9, 7),
#  ('War and Peace', '1915', 7.2, 13),
#  ('The White Pearl', '1915', 1.0, 8),
#  ('Who Pays?', '1915', 6.7, 16),
#  ('Wildfire', '1915', 7.6, 13),
#  ('The Wolf Man', '1915', 8.6, 8),
#  ("The Adventures of Peg o' the Ring", '1916', 4.3, 13),
#  ('Alien Souls', '1916', 5.2, 8),
#  ('American Aristocracy', '1916', 6.3, 57),
#  ('The American Beauty', '1916', 7.0, 11),
#  ('Wolo czawienko', '1916', 5.7, 32),
#  ('Behind the Lines', '1916', 5.5, 6),
#  ('Betty of Greystone', '1916', 5.2, 12),
#  ('The Call of the Cumberlands', '1916', 6.6, 53),
#  ('A Child of the Paris Streets', '1916', 7.0, 9),
#  ('The Children Pay', '1916', 7.6, 35),
#  ('The Children in the House', '1916', 6.6, 552),
#  ('Civilization', '1915', 6.1, 247),
#  ('The Cossack Whip', '1916', 8.5, 44),
#  ('Daphne and the Pirate', '1916', 5.6, 51),
#  ('A Daughter of the Gods', '1916', 7.1, 28),
#  ("The Devil's Needle", '1916', 7.1, 100),
#  ('Diane of the Follies', '1916', 5.9, 50),
#  ('The Dumb Girl of Portici', '1916', 6.4, 60),
#  ('East Lynne', '1916', 5.9, 15),
#  ('The Eternal Grind', '1916', 7.2, 8),
#  ('The Evil Women Do', '1916', 4.0, 6),
#  ('The Fall of a Nation', '1916', 5.2, 30),
#  ('Fifty-Fifty', '1916', 4.9, 8),
#  ('The Foundling', '1916', 5.7, 10),
#  ('Friday the 13th', '1916', 6.0, 41),
#  ("Gloria's Romance", '1916', 6.3, 16),
#  ('Going Straight', '1916', 6.5, 599),
#  ('Gretchen the Greenhorn', '1916', 6.5, 465),
#  ('The Vultures of the Coast', '1915', 6.2, 36),
#  ('The Heart of Nora Flynn', '1916', 5.9, 7),
#  ('The Heart of a Hero', '1916', 6.3, 18),
#  ('Hoodoo Ann', '1916', 6.7, 819),
#  ('Hulda from Holland', '1916', 5.9, 9),
#  ('The Hunted Woman', '1916', 2.1, 9),
#  ('If My Country Should Call', '1916', 6.1, 7),
#  ("Intolerance: Love's Struggle Throughout the Ages", '1916', 7.9, 12707),
#  ('King Lear', '1916', 5.7, 60),
#  ('Less Than the Dust', '1916', 5.9, 19),
#  ('Macbeth', '1916', 6.3, 14),
#  ('The Warrior', '1916', 6.2, 44),
#  ('The Microscope Mystery', '1916', 4.6, 7),
#  ('The Mysteries of Myra', '1916', 6.3, 7),
#  ('The Net', '1916', 7.0, 14),
#  ('Oliver Twist', '1916', 6.6, 16),
#  ('One Day', '1916', 6.0, 8),
#  ('Pillars of Society', '1916', 5.6, 7),
#  ('The Place Beyond the Winds', '1916', 6.2, 11),
#  ('Poor Little Peppina', '1916', 6.4, 47),
#  ('The Prince of Graustark', '1916', 6.0, 7),
#  ('The Rail Rider', '1916', 3.6, 5),
#  ('Ramona', '1916', 6.7, 7),
#  ('Reggie Mixes In', '1916', 6.5, 545),
#  ('The Right to Be Happy', '1916', 6.1, 16),
#  ('Romeo and Juliet', '1916', 6.6, 11),
#  ('Shoes', '1916', 6.7, 158),
#  ('A Sister of Six', '1916', 6.2, 11),
#  ('The Social Secretary', '1916', 6.5, 496),
#  ('Sold for Marriage', '1916', 6.4, 67),
#  ('Tigre reale', '1916', 6.6, 82),
#  ('To Have and to Hold', '1916', 7.2, 12),
#  ('The Trail of the Lonesome Pine', '1916', 7.0, 12),
#  ('Under Two Flags', '1916', 6.4, 10),
#  ('The Vagabond Prince', '1916', 5.0, 6),
#  ('The Victoria Cross', '1916', 4.7, 6),
#  ('War Brides', '1916', 6.8, 8),
#  ('Where Are My Children?', '1916', 6.4, 521),
#  ('The World and the Woman', '1916', 6.2, 38),
#  ('The Adventurer', '1917', 6.6, 8),
#  ('The Babes in the Woods', '1917', 6.8, 10),
#  ('Barbary Sheep', '1917', 6.7, 7),
#  ('Betsy Ross', '1917', 5.0, 37),
#  ('Castles for Two', '1917', 6.6, 8),
#  ('Cleopatra', '1917', 6.0, 286),
#  ("A Doll's House", '1917', 7.4, 10),
#  ('An Even Break', '1917', 6.9, 8),
#  ('The Fall of the Romanoffs', '1917', 7.1, 12),
#  ('The Flame of Youth', '1917', 7.0, 6),
#  ('The Foolish Virgin', '1916', 6.9, 7),
#  ('The Girl Without a Soul', '1917', 6.3, 6),
#  ('A Girl of the Timber Claims', '1917', 5.9, 8),
#  ('Great Expectations', '1917', 6.1, 14),
#  ('The Hand That Rocks the Cradle', '1917', 7.1, 12),
#  ('The House Built Upon Sand', '1916', 6.7, 32),
#  ('Joan the Woman', '1916', 6.5, 463),
#  ('The Law of the North', '1917', 6.0, 6),
#  ('The Little American', '1917', 6.5, 574),
#  ('The Little Princess', '1917', 6.6, 611),
#  ('Madame Du Barry', '1917', 6.0, 6),
#  ('The Man Without a Country', '1917', 6.7, 36),
#  ('The Torture of Silence', '1917', 6.5, 90),
#  ('Les Misérables', '1917', 5.7, 16),
#  ('A Mormon Maid', '1917', 6.2, 67),
#  ('Mothers of Men', '1917', 5.8, 66),
#  ('Nan of Music Mountain', '1917', 4.8, 9),
#  ('On Dangerous Ground', '1917', 9.0, 42),
#  ('One Touch of Nature', '1917', 5.8, 24),
#  ('Patria', '1917', 6.0, 18),
#  ('Polly of the Circus', '1917', 7.8, 31),
#  ('The Poor Little Rich Girl', '1917', 6.8, 1202),
#  ('The Pride of the Clan', '1917', 6.6, 72),
#  ('Rebecca of Sunnybrook Farm', '1917', 7.0, 733),
#  ('Runaway Romany', '1917', 8.4, 46),
#  ('The Sawdust Ring', '1917', 5.9, 8),
#  ('The Scarlet Car', '1917', 5.4, 66),
#  ('The Scarlet Letter', '1917', 6.7, 11),
#  ('She', '1917', 6.4, 8),
#  ('Souls Triumphant', '1917', 7.0, 26),
#  ('A Tale of Two Cities', '1917', 6.3, 95),
#  ('Tepeyac', '1917', 5.3, 27),
#  ('Tom Sawyer', '1917', 6.3, 127),
#  ('Triumph', '1917', 6.0, 7),
#  ('Girl from Stormy Croft', '1917', 6.9, 131),
#  ('The Vicar of Wakefield', '1917', 6.3, 22),
#  ('The Weavers of Life', '1917', 6.8, 8),
#  ('The Whip', '1917', 6.0, 26),
#  ('Young Mother Hubbard', '1917', 7.0, 8),
#  ('All Night', '1918', 6.0, 60),
#  ('The Eyes of the Mummy', '1918', 5.5, 513),
#  ('The Outlaw and His Wife', '1918', 7.2, 1366),
#  ('Betty Takes a Hand', '1918', 7.1, 14),
#  ('Carmen', '1918', 6.2, 234),
#  ('Carmen of the Klondike', '1918', 5.4, 8),
#  ('Cecilia of the Pink Roses', '1918', 8.8, 52),
#  ('The Craving', '1918', 4.8, 44),
#  ('De Luxe Annie', '1918', 7.4, 10),
#  ('The Tenth Symphony', '1918', 6.1, 111),
#  ("A Doll's House", '1918', 7.3, 9),
#  ('Eye for Eye', '1918', 6.1, 7),
#  ('The Eyes of Julia Deep', '1918', 6.7, 30),
#  ('A Fight for Millions: Episode No. 1, The Snare', '1918', 6.8, 5),
#  ('The Floor Below', '1918', 7.4, 17),
#  ('The Forbidden City', '1918', 6.4, 268),
#  ('The Ghost of Rosy Taylor', '1918', 7.3, 28),
#  ('The Girl Who Stayed at Home', '1919', 6.5, 69),
#  ('The Great Adventure', '1918', 7.2, 9),
#  ('The Great Love', '1918', 7.0, 44),
#  ('The Greatest Thing in Life', '1918', 6.9, 55),
#  ('The Gulf Between', '1917', 6.6, 10),
#  ('The Heart of Humanity', '1918', 5.8, 52),
#  ('Hearts of the World', '1918', 6.7, 855),
#  ('The House of Mirth', '1918', 7.0, 11),
#  ('Huck and Tom', '1918', 6.5, 12),
#  ('The Hun Within', '1918', 5.8, 8),
#  ('Joan of Plattsburg', '1918', 5.9, 15),
#  ("Kaiser's Finish", '1918', 4.0, 9),
#  ('The Kaiser, the Beast of Berlin', '1918', 6.1, 19),
#  ('Lest We Forget', '1918', 7.1, 7),
#  ('Little Orphant Annie', '1918', 6.9, 38),
#  ('Little Women', '1918', 6.8, 21),
#  ("M'Liss", '1918', 6.7, 105),
#  ('The Married Virgin', '1918', 6.5, 602),
#  ('The Mask', '1918', 6.3, 7),
#  ('Mickey', '1918', 7.0, 1026),
#  ('My Cousin', '1918', 6.5, 22),
#  ('My Four Years in Germany', '1918', 5.8, 32),
#  ('The Ballet Girl', '1918', 7.0, 8),
#  ('Opportunity', '1918', 6.5, 6),
#  ('Over the Top', '1918', 7.4, 7),
#  ('A Petticoat Pilot', '1918', 7.0, 18),
#  ('Rich Man, Poor Man', '1918', 7.1, 7),
#  ('Riders of the Night', '1918', 6.7, 7),
#  ('A Romance of Happy Valley', '1919', 6.7, 303),
#  ('Salome', '1918', 6.1, 22),
#  ('Shark Monroe', '1918', 5.2, 12),
#  ('Shifting Sands', '1918', 7.3, 674),
#  ('Society for Sale', '1918', 7.3, 9),
#  ('Station Content', '1918', 6.6, 16),
#  ('Stella Maris', '1918', 7.3, 1297),
#  ('Till I Come Back to You', '1918', 5.1, 7),
#  ('The Unbeliever', '1918', 6.1, 97),
#  ("Uncle Tom's Cabin", '1918', 5.0, 5),
#  ('Virtuous Wives', '1918', 5.1, 12),
#  ('Vive la France!', '1918', 5.5, 8),
#  ('When Do We Eat?', '1918', 6.1, 8),
#  ('When Men Betray', '1918', 5.8, 5),
#  ('The Whispering Chorus', '1918', 6.7, 234),
#  ('Woman', '1918', 5.5, 11),
#  ('The Woman in the Web', '1918', 5.1, 8),
#  ('The Yellow Ticket', '1918', 6.7, 9),
#  ('The A.B.C. of Love', '1919', 6.6, 12),
#  ('Different from the Others', '1919', 6.9, 992),
#  ('Anne of Green Gables', '1919', 7.0, 53),
#  ('Auction of Souls', '1919', 6.4, 915),
#  ('Behind the Door', '1919', 7.2, 130),
#  ('The Belle of New York', '1919', 7.5, 46),
#  ('Blind Husbands', '1919', 6.9, 1239),
#  ('Bolshevism on Trial', '1919', 5.6, 24),
#  ('Broken Blossoms', '1919', 7.6, 8492),
#  ('The Brute Breaker', '1919', 6.0, 8),
#  ('The Busher', '1919', 6.5, 615),
#  ('Checkers', '1919', 5.0, 8),
#  ('The Cinema Murder', '1919', 8.3, 35),
#  ('The Climbers', '1919', 7.3, 7),
#  ('Daddy-Long-Legs', '1919', 7.4, 1269),
#  ('The Delicious Little Devil', '1919', 6.7, 788),
#  ('Deliverance', '1919', 7.0, 42),
#  ('The Exquisite Thief', '1919', 5.4, 5),
#  ('Eyes of Youth', '1919', 6.6, 626),
#  ('The Fall of Babylon', '1919', 6.8, 81),
#  ('The False Faces', '1919', 6.0, 54),
#  ("Fool's Gold", '1919', 4.1, 8),
#  ('For Better, for Worse', '1919', 7.6, 684),
#  ('A Gay Old Dog', '1919', 5.7, 7),
#  ('Girl from Nowhere', '1919', 5.4, 10),
#  ('The Glorious Lady', '1919', 6.6, 12),
#  ('The Golden Shower', '1919', 5.3, 10),
#  ('The Grim Game', '1919', 6.9, 234),
#  ('Hard Boiled', '1919', 6.2, 8),
#  ('The Haunted Bedroom', '1919', 6.9, 14),
#  ("Heart o' the Hills", '1919', 6.6, 495),
#  ('The Heart of Wetona', '1919', 5.8, 12),
#  ("Sir Arne's Treasure", '1919', 7.1, 1064),
#  ("J'accuse!", '1919', 7.4, 1219),
#  ('Johnny Get Your Gun', '1919', 7.1, 19),
#  ('Kathleen Mavourneen', '1919', 5.7, 10),
#  ('Emerald of Death', '1919', 7.0, 34),
#  ('The Life Line', '1919', 5.2, 13),
#  ('The Lost Battalion', '1919', 6.9, 67),
#  ("Love's Prisoner", '1919', 6.5, 53),
#  ('Luck and Pluck', '1919', 6.4, 10),
#  ('The Lurking Peril', '1919', 2.9, 12),
#  ('Male and Female', '1919', 7.8, 1636),
#  ('The Man Hunter', '1919', 6.6, 10),
#  ('The Man Who Turned White', '1919', 5.7, 10),
#  ("A Man's Fight", '1919', 1.0, 8),
#  ('The Masked Rider', '1919', 6.7, 9),
#  ('The Miracle Man', '1919', 6.1, 140),
#  ('More Deadly Than the Male', '1919', 6.7, 10),
#  ('The Mother and the Law', '1919', 7.1, 143),
#  ('Mrs. Wiggs of the Cabbage Patch', '1919', 6.7, 18),
#  ("My Husband's Other Wife", '1920', 4.8, 5),
#  ('The Other Half', '1919', 6.2, 13),
#  ('Paid in Full', '1919', 7.1, 19),
#  ('The President', '1919', 6.4, 705),
#  ('The Red Lantern', '1919', 7.2, 30),
#  ('The Right to Happiness', '1919', 5.2, 6),
#  ('The Secret Garden', '1919', 6.2, 12),
#  ('The Shepherd of the Hills', '1919', 5.9, 7),
#  ('Should a Woman Tell?', '1919', 6.8, 8),
#  ('Soldiers of Fortune', '1919', 6.1, 11),
#  ('Fairy of Solbakken', '1919', 6.6, 39),
#  ('Theodora', '1921', 6.9, 15),
#  ('The Test of Honor', '1919', 7.0, 21),
#  ('The Tong Man', '1919', 6.5, 55),
#  ('True Heart Susie', '1919', 7.2, 1468),
#  ('Victory', '1919', 6.5, 298),
#  ('A Tale of Two Worlds', '1921', 6.2, 26),
#  ('When Bearcat Went Dry', '1919', 6.0, 11),
#  ('The Wicked Darling', '1919', 6.5, 301),
#  ('The Witness for the Defense', '1919', 8.4, 17),
#  ('The World and Its Woman', '1919', 6.9, 10),
#  ('Evening - Night - Morning', '1920', 6.9, 24),
#  ('The Adventurer', '1920', 1.0, 8),
#  ('Anna Boleyn', '1920', 6.7, 509),
#  ('April Folly', '1920', 8.5, 68),
#  ('Below the Surface', '1920', 6.7, 14),
#  ("Leaves From Satan's Book", '1920', 6.8, 1007),
#  ('The Confession', '1920', 5.7, 6),
#  ('The Copperhead', '1920', 6.8, 10),
#  ('The Cradle of Courage', '1920', 5.8, 36),
#  ('The Dark Mirror', '1920', 5.8, 9),
#  ('Dinty', '1920', 7.8, 50),
#  ('Down Home', '1920', 7.5, 10),
#  ('Dr. Jekyll and Mr. Hyde', '1920', 7.0, 4294),
#  ('Excuse My Dust', '1920', 6.0, 26),
#  ('For the Soul of Rafael', '1920', 5.4, 7),
#  ('The Fortune Teller', '1920', 7.2, 11),
#  ('Journey into the Night', '1921', 6.6, 255),
#  ('Go and Get It', '1920', 4.5, 11),
#  ("Headin' Home", '1920', 5.3, 233),
#  ('Her Elephant Man', '1920', 7.0, 8),
#  ("Hitchin' Posts", '1920', 4.6, 25),
#  ('Huckleberry Finn', '1920', 6.5, 69),
#  ('Humoresque', '1920', 6.7, 109),
#  ('The Idol Dancer', '1920', 5.7, 68),
#  ('If I Were King', '1920', 6.9, 8),
#  ('The Jack-Knife Man', '1920', 6.9, 90),
#  ('Just Pals', '1920', 6.6, 295),
#  ('Kismet', '1920', 6.3, 19),
#  ('The Last of the Mohicans', '1920', 6.9, 1010),
#  ('The Life of the Party', '1920', 6.1, 79),
#  ('The Love Flower', '1920', 6.6, 81),
#  ('Mid-Channel', '1920', 5.9, 18),
#  ('Miss Nobody', '1920', 1.8, 8),
#  ('Nomads of the North', '1920', 5.9, 169),
#  ('Nurse Marjorie', '1920', 7.0, 45),
#  ('Over the Hill to the Poorhouse', '1920', 4.7, 7),
#  ('The Penalty', '1920', 7.5, 1820),
#  ('Pink Tights', '1920', 5.9, 8),
#  ('Polly with a Past', '1920', 4.2, 6),
#  ('Pollyanna', '1920', 6.8, 306),
#  ('The Price of Redemption', '1920', 5.0, 7),
#  ('The Prince of Avenue A', '1920', 3.0, 23),
#  ('The Prince and the Pauper', '1920', 5.2, 10),
#  ("The Parson's Widow", '1920', 7.4, 929),
#  ('The Restless Sex', '1920', 8.9, 82),
#  ('Sex', '1920', 6.4, 246),
#  ('The Sign on the Door', '1921', 4.5, 11),
#  ('Silk Husbands and Calico Wives', '1920', 7.0, 6),
#  ('The Silver Horde', '1920', 6.1, 14),
#  ('Something to Think About', '1920', 8.1, 549),
#  ('The Soul of Youth', '1920', 7.3, 79),
#  ('Stronger Than Death', '1920', 7.1, 9),
#  ('Suds', '1920', 6.5, 190),
#  ('Sumurun', '1920', 6.3, 558),
#  ('The Toll Gate', '1920', 6.5, 169),
#  ('From Morn to Midnight', '1920', 7.0, 356),
#  ('Way Down East', '1920', 7.8, 4574),
#  ('Weltbrand', '1920', 7.0, 8),
#  ('What Women Want', '1920', 6.9, 9),
#  ('While New York Sleeps', '1920', 6.9, 17),
#  ('Whispering Devils', '1920', 5.3, 6),
#  ('The White Dove', '1920', 5.6, 7),
#  ('Within Our Gates', '1920', 6.4, 1929),
#  ('A Woman in Grey', '1920', 6.6, 34),
#  ('The Woman in the Suitcase', '1920', 6.2, 12),
#  ('The Wonder Man', '1920', 6.9, 11),
#  ('The Wonderful Chance', '1920', 6.1, 25),
#  ('Yes or No', '1920', 6.3, 7),
#  ('The Ace of Hearts', '1921', 6.9, 985),
#  ('The Affairs of Anatol', '1921', 7.8, 1177),
#  ('Annabelle Lee', '1921', 5.5, 18),
#  ('The Barbarian', '1921', 5.0, 8),
#  ('Beau Revel', '1921', 5.5, 17),
#  ('The Wildcat', '1921', 7.1, 949),
#  ('Black Beauty', '1921', 6.1, 9),
#  ("The Black Panther's Cub", '1921', 5.3, 6),
#  ('The Blazing Trail', '1921', 6.8, 8),
#  ('The Bonnie Brier Bush', '1921', 6.8, 25),
#  ('Camille', '1921', 6.6, 825),
#  ('The Child Thou Gavest Me', '1921', 5.8, 9),
#  ('Christian Wahnschaffe, 2. Teil - Die Flucht aus dem goldenen Kerker',
#   '1921',
#   6.5,
#   10),
#  ('The Conquering Power', '1921', 6.9, 373),
#  ('The Devil Within', '1921', 5.5, 11),
#  ('The Devil', '1921', 6.3, 36),
#  ('Disraeli', '1921', 6.8, 15),
#  ('Dream Street', '1921', 6.0, 109),
#  ('Forbidden Fruit', '1921', 7.0, 92),
#  ('The Four Horsemen of the Apocalypse', '1921', 7.8, 2881),
#  ('The Great Moment', '1921', 6.5, 10),
#  ('Hail the Woman', '1921', 7.0, 43),
#  ('Jackie', '1921', 5.2, 29),
#  ('Jane Eyre', '1921', 6.6, 7),
#  ('The Kid', '1921', 8.3, 95102),
#  ('The Phantom Carriage', '1921', 8.1, 8789),
#  ('Ladies Must Live', '1921', 6.9, 21),
#  ('Circus Jim', '1921', 6.0, 6),
#  ('Little Lord Fauntleroy', '1921', 7.0, 249),
#  ('The Little Minister', '1921', 7.0, 33),
#  ('Lotus Blossom', '1921', 5.3, 33),
#  ('The Love Light', '1921', 6.7, 323),
#  ('Love Never Dies', '1921', 6.8, 81),
#  ('The Love Special', '1921', 6.9, 10),
#  ('Madame Peacock', '1920', 6.6, 8),
#  ('Miss Lulu Bett', '1921', 7.1, 275),
#  ('My Boy', '1921', 6.1, 224),
#  ('Destiny', '1921', 7.7, 4494),
#  ('No Woman Knows', '1921', 5.7, 6),
#  ('Orphans of the Storm', '1921', 7.8, 4368),
#  ('Passion Flower', '1921', 6.1, 9),
#  ('The Queen of Sheba', '1921', 6.9, 38),
#  ('Mad Love', '1921', 6.9, 110),
#  ('Scherben', '1921', 6.6, 192),
#  ('The Haunted Castle', '1921', 6.3, 1206),
#  ('The Sea Lion', '1921', 6.6, 81),
#  ('Sentimental Tommy', '1921', 6.3, 6),
#  ('The Sheik', '1921', 7.1, 2891),
#  ('Queen of the Turf', '1921', 5.9, 15),
#  ('The Single Track', '1921', 3.0, 15),
#  ('The Sky Pilot', '1921', 7.0, 83),
#  ('The Sting of the Lash', '1921', 5.0, 5),
#  ('Stranger Than Fiction', '1921', 5.8, 5),
#  ('La terre', '1921', 6.7, 130),
#  ('Through the Back Door', '1921', 6.9, 146),
#  ("Tol'able David", '1921', 7.8, 1659),
#  ('Too Wise Wives', '1921', 6.1, 121),
#  ('Torgus', '1921', 6.0, 23),
#  ('Vier um die Frau', '1921', 6.4, 283),
#  ('What Do Men Want?', '1921', 6.6, 11),
#  ('What No Man Knows', '1921', 6.7, 11),
#  ('Whispering Shadows', '1921', 5.3, 12),
#  ('The Whistle', '1921', 6.6, 36),
#  ('The Witching Hour', '1921', 6.8, 8),
#  ('Without Benefit of Clergy', '1921', 5.2, 6),
#  ('The Wonderful Thing', '1921', 5.4, 8),
#  ('The Altar Stairs', '1922', 3.6, 5),
#  ('Anna Ascends', '1922', 4.9, 9),
#  ('Back Pay', '1922', 7.0, 21),
#  ("Beauty's Worth", '1922', 8.0, 642),
#  ('Beyond the Rainbow', '1922', 6.7, 7),
#  ('Beyond the Rocks', '1922', 7.6, 2162),
#  ('A Blind Bargain', '1922', 6.2, 21),
#  ('Blood and Sand', '1922', 7.2, 1159),
#  ('Der brennende Acker', '1922', 7.2, 507),
#  ('Broken Chains', '1922', 5.1, 9),
#  ('Captain Fly-by-Night', '1922', 6.0, 9),
#  ('Conquering the Woman', '1922', 5.8, 5),
#  ('The Dictator', '1922', 1.6, 8),
#  ("A Doll's House", '1922', 6.2, 9),
#  ('Down to the Sea in Ships', '1922', 6.2, 309),
#  ('Fair Lady', '1922', 5.0, 7),
#  ('Os Faroleiros', '1922', 6.4, 36),
#  ('Flesh and Blood', '1922', 6.5, 131),
#  ('Flesh and Spirit', '1922', 6.9, 9),
#  ('A Fool There Was', '1922', 6.7, 7),
#  ('Foolish Wives', '1922', 7.2, 2647),
#  ('The Headless Horseman', '1922', 5.0, 195),
#  ('Human Hearts', '1922', 6.7, 7),
#  ('Hungry Hearts', '1922', 6.7, 19),
#  ('The Infidel', '1922', 4.6, 8),
#  ('Kindred of the Dust', '1922', 6.6, 9),
#  ('Little Miss Smiles', '1922', 3.7, 22),
#  ('Lorna Doone', '1922', 6.9, 244),
#  ('Manslaughter', '1922', 7.3, 371),
#  ('Marizza', '1922', 6.6, 47),
#  ('Merry-Go-Round', '1923', 6.8, 261),
#  ('Monte Cristo', '1922', 7.3, 290),
#  ('My Wild Irish Rose', '1922', 3.0, 8),
#  ('Nathan der Weise', '1922', 6.9, 100),
#  ('No Trespassing', '1922', 6.9, 22),
#  ('Oliver Twist', '1922', 6.8, 658),
#  ('Omar the Tentmaker', '1922', 6.8, 8),
#  ('The House Surrounded', '1922', 6.9, 10),
#  ("Peg o' My Heart", '1922', 6.9, 78),
#  ('Phantom', '1922', 7.0, 1374),
#  ('The Pride of Palomar', '1922', 6.8, 12),
#  ('Real Adventure', '1922', 6.6, 5),
#  ('Reckless Youth', '1922', 6.2, 13),
#  ('Salomé', '1922', 6.6, 728),
#  ('Warning Shadows', '1923', 7.0, 765),
#  ('The Seventh Day', '1922', 7.9, 87),
#  ('Sherlock Holmes', '1922', 5.8, 516),
#  ('Silver Wings', '1922', 4.1, 23),
#  ('Sky High', '1922', 5.9, 128),
#  ("Smilin' Through", '1922', 7.2, 57),
#  ('The Snowshoe Trail', '1922', 3.2, 12),
#  ('The Little Napoleon', '1923', 5.7, 13),
#  ('The Song of Love', '1923', 6.6, 16),
#  ('The Smiling Madame Beudet', '1923', 6.8, 1767),
#  ('Tess of the Storm Country', '1922', 7.2, 389),
#  ('The Third Alarm', '1922', 6.9, 12),
#  ('Tillie', '1922', 6.8, 6),
#  ("Timothy's Quest", '1922', 7.6, 57),
#  ('The Toll of the Sea', '1922', 6.7, 589),
#  ('Trifling Women', '1922', 6.7, 9),
#  ('Turn to the Right', '1922', 6.2, 11),
#  ('Under Two Flags', '1922', 6.7, 18),
#  ('Unseeing Eyes', '1923', 6.0, 7),
#  ('The Valley of Silent Men', '1922', 6.8, 6),
#  ('The Village Blacksmith', '1922', 5.0, 62),
#  ('The Wall Flower', '1922', 6.2, 5),
#  ('The Loves of Pharaoh', '1922', 6.6, 412),
#  ('When Knighthood Was in Flower', '1922', 8.0, 896),
#  ('Wild Honey', '1922', 2.2, 10),
#  ('The Worldly Madonna', '1922', 5.3, 15),
#  ('Roman Candles', '1920', 4.8, 6),
#  ('The Young Diana', '1922', 7.8, 54),
#  ('The Young Rajah', '1922', 6.9, 345),
#  ('All the Brothers Were Valiant', '1923', 6.4, 18),
#  ('All for Money', '1923', 5.8, 12),
#  ('Anna Christie', '1923', 7.1, 60),
#  ('Ashes of Vengeance', '1923', 6.6, 32),
#  ('The Red Inn', '1923', 6.9, 76),
#  ('Bella Donna', '1923', 6.6, 12),
#  ('Big Dan', '1923', 4.2, 9),
#  ('Boston Blackie', '1923', 6.9, 9),
#  ('Brass', '1923', 6.5, 8),
#  ('The Bright Shawl', '1923', 6.6, 30),
#  ('Burning Words', '1923', 6.0, 10),
#  ('Cameo Kirby', '1923', 7.4, 301),
#  ('A Chapter in Her Life', '1923', 4.9, 8),
#  ('Circus Days', '1923', 6.6, 25),
#  ('A Clouded Name', '1923', 6.2, 24),
#  ('The Faithful Heart', '1923', 7.7, 932),
#  ('The Courtship of Myles Standish', '1923', 5.6, 12),
#  ("Cupid's Fireman", '1923', 5.1, 15),
#  ('Daddy', '1923', 6.6, 7),
#  ('Drifting', '1923', 6.8, 16),
#  ('The Hell Ship', '1923', 7.3, 69),
#  ('The Eleventh Hour', '1923', 5.2, 5),
#  ('Enemies of Women', '1923', 3.8, 10),
#  ('The Fighting Blade', '1923', 5.5, 16),
#  ('Flaming Youth', '1923', 7.4, 41),
#  ('The Fog', '1923', 7.0, 27),
#  ('The Blizzard', '1923', 7.1, 132),
#  ('The Saga of Gösta Berling', '1924', 7.3, 972),
#  ('Homeward Bound', '1923', 5.2, 18),
#  ('Human Wreckage', '1923', 7.4, 9),
#  ('The Hunchback of Notre Dame', '1923', 7.3, 4252),
#  ('Swords and the Woman', '1923', 4.0, 11),
#  ('Crown of Thorns', '1923', 6.1, 34),
#  ('Is Money Everything?', '1923', 6.2, 12),
#  ('Jazzmania', '1923', 7.2, 6),
#  ('Jealous Husbands', '1923', 5.0, 5),
#  ('Die Lawine', '1923', 5.6, 48),
#  ("Let's Go", '1923', 5.4, 15),
#  ('Little Church Around the Corner', '1923', 6.1, 18),
#  ('Long Live the King', '1923', 7.2, 11),
#  ('Mary of the Movies', '1923', 7.0, 6),
#  ('Maytime', '1923', 6.9, 17),
#  ('North of Hudson Bay', '1923', 5.2, 58),
#  ('The Nth Commandment', '1923', 6.6, 7),
#  ('Good Luck', '1923', 7.2, 19),
#  ('Penrod and Sam', '1923', 6.3, 6),
#  ('Ponjola', '1923', 6.2, 9),
#  ('Prodigal Daughters', '1923', 7.0, 10),
#  ('Quicksands', '1923', 5.7, 7),
#  ('The Wheel', '1923', 7.6, 1557),
#  ('Scaramouche', '1923', 7.2, 456),
#  ('The Shock', '1923', 6.6, 344),
#  ('The Silent Command', '1923', 6.1, 55),
#  ('Slave of Desire', '1923', 2.2, 6),
#  ('Soul of the Beast', '1923', 7.0, 33),
#  ('Souls for Sale', '1923', 7.2, 738),
#  ('The Spider and the Rose', '1923', 5.3, 7),
#  ('The Steel Trail', '1923', 5.1, 10),
#  ('Der steinerne Reiter', '1923', 7.0, 50),
#  ('Die Straße', '1923', 7.1, 302),
#  ("New Year's Eve", '1924', 6.4, 100),
#  ('The Ten Commandments', '1923', 7.0, 1698),
#  ('Tiger Rose', '1923', 6.8, 16),
#  ('The Tragedy of Love', '1923', 5.2, 14),
#  ('Trimmed in Scarlet', '1923', 7.0, 7),
#  ('The Untameable', '1923', 7.3, 13),
#  ('Where the North Begins', '1923', 7.1, 42),
#  ('The White Rose', '1923', 7.1, 133),
#  ('The White Sister', '1923', 7.0, 360),
#  ('White Tiger', '1923', 6.7, 94),
#  ('Within the Law', '1923', 7.3, 80),
#  ('A Woman of Paris: A Drama of Fate', '1923', 7.1, 4284),
#  ('Zaza', '1923', 8.0, 726),
#  ('The Dramatic Life of Abraham Lincoln', '1924', 5.3, 18),
#  ('Aelita: Queen of Mars', '1924', 6.6, 2110),
#  ('The Age of Innocence', '1924', 6.6, 27),
#  ('America', '1924', 6.5, 318),
#  ('The Arab', '1924', 6.7, 19),
#  ('The Arizona Express', '1924', 6.9, 16),
#  ('The Average Woman', '1924', 6.4, 16),
#  ('Barbara Frietchie', '1924', 6.4, 25),
#  ('Beau Brummel', '1924', 6.9, 368),
#  ('Black Lightning', '1924', 5.2, 19),
#  ('Black Oxen', '1923', 6.0, 107),
#  ('A Boy of Flanders', '1924', 7.5, 11),
#  ('Butterfly', '1924', 7.0, 13),
#  ('Captain January', '1924', 7.1, 188),
#  ('The Chechahcos', '1923', 6.8, 187),
#  ('The Circus Cowboy', '1924', 3.7, 6),
#  ('Code of the Sea', '1924', 6.3, 19),
#  ("Dante's Inferno", '1924', 6.1, 81),
#  ('Dorothy Vernon of Haddon Hall', '1924', 7.3, 104),
#  ('Dynamite Dan', '1924', 5.9, 39),
#  ('Empty Hands', '1924', 5.3, 11),
#  ('The Enchanted Cottage', '1924', 7.9, 587),
#  ('The Family Secret', '1924', 6.5, 104),
#  ('A Fight for Honor', '1924', 5.1, 8),
#  ('The Fighting Adventurer', '1924', 6.6, 5),
#  ('Whirlpool of Fate', '1925', 6.8, 498),
#  ('Find Your Man', '1924', 4.5, 11),
#  ('Grit', '1924', 4.6, 9),
#  ('He Who Gets Slapped', '1924', 7.9, 2675),
#  ('Hearts of Oak', '1924', 3.2, 23),
#  ('Her Love Story', '1924', 6.3, 9),
#  ('His Hour', '1924', 6.5, 11),
#  ('Hoodman Blind', '1923', 3.6, 22),
#  ('The Hoosier Schoolmaster', '1924', 6.4, 5),
#  ('The Humming Bird', '1924', 7.6, 11),
#  ('Into the Net', '1924', 6.0, 6),
#  ("Isn't Life Wonderful", '1924', 7.5, 256),
#  ('Janice Meredith', '1924', 8.3, 615),
#  ('Kentucky Days', '1923', 1.0, 6),
#  ('The Last Laugh', '1924', 8.1, 10996),
#  ('Lilies of the Field', '1924', 6.8, 17),
#  ('The Lover of Camille', '1924', 7.1, 13),
#  ('Manhandled', '1924', 8.0, 902),
#  ('Michael', '1924', 7.3, 1398),
#  ('Miracle of the Wolves', '1924', 6.7, 60),
#  ('Monsieur Beaucaire', '1924', 7.8, 430),
#  ('The Net', '1923', 7.0, 49),
#  ("Die Nibelungen: Kriemhild's Revenge", '1924', 7.9, 3486),
#  ('Die Nibelungen: Siegfried', '1924', 8.1, 4601),
#  ('Husbands or Lovers', '1924', 6.5, 65),
#  ('One Night in Rome', '1924', 5.1, 11),
#  ('Pied Piper Malone', '1924', 6.5, 6),
#  ('Quo Vadis?', '1924', 5.9, 51),
#  ('The Reckless Age', '1924', 6.2, 8),
#  ('The Red Lily', '1924', 7.2, 388),
#  ('The Rejected Woman', '1924', 7.2, 12),
#  ('Roaring Rails', '1924', 6.5, 50),
#  ('Romola', '1924', 6.6, 136),
#  ('A Sainted Devil', '1924', 7.7, 14),
#  ('The Sea Hawk', '1924', 7.3, 411),
#  ('Secrets', '1924', 7.8, 203),
#  ('Secrets of the Night', '1924', 7.0, 14),
#  ('The Signal Tower', '1924', 6.6, 35),
#  ('The Moon of Israel', '1924', 5.6, 61),
#  ('So Big', '1924', 7.0, 13),
#  ('A Society Scandal', '1924', 7.3, 53),
#  ('A Son of the Sahara', '1924', 4.5, 10),
#  ('Strike', '1925', 7.6, 6210),
#  ('Terror', '1924', 7.1, 7),
#  ("Tess of the D'Urbervilles", '1924', 4.8, 5),
#  ('A Thief in Paradise', '1925', 6.3, 6),
#  ('The Tomboy', '1924', 5.7, 6),
#  ('The Torrent', '1924', 6.7, 12),
#  ('The Turmoil', '1924', 6.7, 7),
#  ('Twenty Dollars a Week', '1924', 6.1, 14),
#  ('White Shadows', '1924', 6.4, 186),
#  ('The White Sin', '1924', 7.4, 14),
#  ('Wild Oranges', '1924', 7.0, 398),
#  ('Wine of Youth', '1924', 8.0, 283),
#  ('The Wolf Man', '1923', 5.6, 14),
#  ('Wolves of the North', '1924', 2.3, 10),
#  ('Woman to Woman', '1923', 7.1, 48),
#  ('The Ace of Spades', '1925', 5.6, 9),
#  ('Adventure', '1925', 5.5, 21),
#  ('The Adventurous Sex', '1925', 6.1, 17),
#  ('Raffles: The Amateur Cracksman', '1925', 4.9, 35),
#  ('As Man Desires', '1925', 2.5, 8),
#  ('Barriers Burned Away', '1925', 5.6, 7),
#  ('The Big Parade', '1925', 8.2, 5687),
#  ('Body and Soul', '1925', 6.3, 591),
#  ('Battleship Potemkin', '1925', 8.0, 47868),
#  ('The Circle', '1925', 6.7, 474),
#  ('The Coast Patrol', '1925', 6.3, 30),
#  ('The Coming of Amos', '1925', 6.7, 38),
#  ('The Dancers', '1925', 6.7, 26),
#  ('The Dark Angel', '1925', 7.4, 18),
#  ('Déclassé', '1925', 5.8, 11),
#  ('The Dressmaker from Paris', '1925', 7.1, 9),
#  ('Master of the House', '1925', 7.2, 1485),
#  ('The case of the murder of Tariel Mklavadze', '1925', 6.1, 12),
#  ('The Eagle', '1925', 7.2, 1538),
#  ('The Phantom of the Moulin-Rouge', '1925', 6.4, 110),
#  ('The Living Dead Man', '1926', 7.1, 283),
#  ('The Fighting Heart', '1925', 3.3, 22),
#  ('Fighting the Flames', '1925', 6.2, 8),
#  ('The Joyless Street', '1925', 7.4, 1254),
#  ('The Gold Rush', '1925', 8.2, 88829),
#  ('The Golden Bed', '1925', 7.3, 20),
#  ('Greed', '1924', 7.9, 8220),
#  ('Mother of Mine', '1926', 6.9, 177),
#  ('Head Winds', '1925', 6.3, 14),
#  ('Headlines', '1925', 2.6, 9),
#  ('The Heart of a Siren', '1925', 5.9, 7),
#  ('His People', '1925', 7.3, 18),
#  ('The Home Maker', '1925', 6.0, 6),
#  ('Irish Luck', '1925', 1.4, 17),
#  ('Justice of the Far North', '1925', 5.0, 7),
#  ('Charles XII', '1925', 7.5, 10),
#  ('The Keeper of the Bees', '1925', 7.2, 13),
#  ('Kentucky Pride', '1925', 5.7, 62),
#  ('Lady of the Night', '1925', 6.2, 507),
#  ('The Last Edition', '1925', 6.0, 11),
#  ('Lazybones', '1925', 7.6, 436),
#  ("Lightnin'", '1925', 5.9, 84),
#  ('Lights of Old Broadway', '1925', 8.3, 389),
#  ('Little Annie Rooney', '1925', 7.5, 794),
#  ('Lorraine of the Lions', '1925', 6.3, 27),
#  ('The Love Gamble', '1925', 5.7, 6),
#  ('The Lucky Devil', '1925', 6.6, 16),
#  ('The Mad Whirl', '1925', 7.5, 20),
#  ('The Masked Bride', '1925', 6.5, 11),
#  ('The Merry Widow', '1925', 8.0, 2010),
#  ('The Midnight Girl', '1925', 6.0, 58),
#  ('The Midshipman', '1925', 5.0, 9),
#  ('Les Misérables', '1925', 6.7, 46),
#  ("My Lady's Lips", '1925', 6.7, 7),
#  ('Old Clothes', '1925', 2.3, 83),
#  ('The Only Thing', '1925', 1.7, 74),
#  ("The Other Woman's Story", '1925', 6.0, 5),
#  ('Pampered Youth', '1925', 5.9, 15),
#  ('Parisian Love', '1925', 6.2, 192),
#  ('The Pleasure Garden', '1925', 6.0, 1880),
#  ('Pretty Ladies', '1925', 2.9, 124),
#  ('Proud Flesh', '1925', 6.4, 86),
#  ('The Rag Man', '1925', 7.2, 268),
#  ('The Red Kimona', '1925', 6.5, 224),
#  ('Riders of the Purple Sage', '1925', 6.6, 144),
#  ('The Road to Yesterday', '1925', 6.8, 105),
#  ('Rugged Water', '1925', 7.4, 16),
#  ('S.O.S. Perils of the Sea', '1925', 6.1, 9),
#  ('Sally, Irene and Mary', '1925', 2.6, 110),
#  ('The Salvation Hunters', '1925', 6.8, 282),
#  ('School for Wives', '1925', 5.9, 12),
#  ('Ship of Souls', '1925', 5.0, 7),
#  ('The Shock Punch', '1925', 6.9, 8),
#  ('Smouldering Fires', '1925', 7.1, 72),
#  ('Soul-Fire', '1925', 7.2, 106),
#  ('Speed Madness', '1925', 7.0, 8),
#  ('Das Spielzeug von Paris', '1925', 6.1, 45),
#  ('The City Without Jews', '1924', 6.4, 114),
#  ('Stella Dallas', '1925', 7.5, 212),
#  ('The Street of Forgotten Men', '1925', 6.7, 14),
#  ('Thank You', '1925', 4.4, 27),
#  ('That Royle Girl', '1925', 6.6, 10),
#  ('Too Many Kisses', '1925', 7.0, 27),
#  ('Tricks', '1925', 5.9, 7),
#  ('Dance Fever', '1925', 5.8, 10),
#  ('The Unchastened Woman', '1925', 7.0, 80),
#  ('The Unholy Three', '1925', 7.3, 1503),
#  ('Up the Ladder', '1925', 6.7, 23),
#  ('Variety', '1925', 7.6, 809),
#  ('Slums of Berlin', '1925', 7.1, 48),
#  ('Faces of Children', '1925', 7.9, 620),
#  ('The Waltz Dream', '1925', 6.6, 22),
#  ('The Wanderer', '1925', 6.4, 14),
#  ('Winds of Chance', '1925', 7.3, 40),
#  ('Wolfblood', '1925', 5.7, 214),
#  ('A Woman of the World', '1925', 7.1, 105),
#  ('The Wrongdoers', '1925', 6.5, 6),
#  ('Zander the Great', '1925', 8.3, 550),
#  ('The Chronicles of the Gray House', '1925', 6.8, 116),
#  ('Heart of an Actress', '1924', 7.3, 10),
#  ('Abrek Zaur', '1926', 5.3, 17),
#  ('Aloma of the South Seas', '1926', 6.1, 8),
#  ('Bardelys the Magnificent', '1926', 7.8, 950),
#  ('Beau Geste', '1926', 7.1, 304),
#  ('The Belle of Broadway', '1926', 7.6, 33),
#  ('The Bells', '1926', 6.6, 312),
#  ('Ben-Hur: A Tale of the Christ', '1925', 8.0, 6794),
#  ('Bertha, the Sewing Machine Girl', '1926', 7.0, 7),
#  ("The Better 'Ole", '1926', 6.4, 188),
#  ('The Big Show', '1926', 6.8, 6),
#  ('The Blackbird', '1926', 6.9, 580),
#  ('The Blind Goddess', '1926', 4.6, 10),
#  ('The Blue Eagle', '1926', 5.5, 127),
#  ('La Bohème', '1926', 7.8, 1352),
#  ('Breed of the Sea', '1926', 5.2, 9),
#  ('Broken Hearts of Hollywood', '1926', 6.8, 6),
#  ('Brown of Harvard', '1926', 8.2, 1352),
#  ('The Canadian', '1926', 7.7, 24),
#  ('Carmen', '1926', 6.9, 74),
#  ('The College Boob', '1926', 7.0, 5),
#  ('The Cowboy Cop', '1926', 7.0, 9),
#  ("The Devil's Circus", '1926', 6.8, 82),
#  ("Devil's Island", '1926', 7.6, 21),
#  ('Dürfen wir schweigen?', '1926', 6.9, 8),
#  ('Exquisite Sinner', '1926', 6.4, 8),
#  ('Fangs of Justice', '1926', 6.3, 7),
#  ('Faust', '1926', 8.1, 12531),
#  ('The Fire Brigade', '1926', 7.6, 29),
#  ('Flesh and the Devil', '1926', 8.0, 3694),
#  ('A Sister of Six', '1926', 7.2, 14),
#  ('The Flying Horseman', '1926', 6.4, 8),
#  ('For Alimony Only', '1926', 7.1, 11),
#  ('Secrets of a Soul', '1926', 7.0, 569),
#  ('God Gave Me Twenty Cents', '1926', 5.2, 6),
#  ('The Greater Glory', '1926', 7.1, 8),
#  ('Der heilige Berg', '1926', 6.8, 575),
#  ("Her Man o' War", '1926', 7.5, 8),
#  ('His Jazz Bride', '1926', 7.4, 7),
#  ('The Ice Flood', '1926', 6.3, 27),
#  ('The Isle of Retribution', '1926', 1.8, 9),
#  ('The Johnstown Flood', '1926', 6.3, 48),
#  ('Just Suppose', '1926', 7.4, 95),
#  ('A Kiss for Cinderella', '1925', 7.0, 60),
#  ('The Kreutzer Sonata', '1927', 6.6, 42),
#  ('Kreuzzug des Weibes', '1926', 7.3, 9),
#  ('A Page of Madness', '1926', 7.6, 2265),
#  ('The Little Irish Girl', '1926', 2.3, 11),
#  ('The Lodger: A Story of the London Fog', '1927', 7.3, 8912),
#  ("Love 'Em and Leave 'Em", '1926', 7.0, 183),
#  ('Maciste in Hell', '1925', 6.9, 369),
#  ("Madame Doesn't Want Children", '1926', 6.2, 12),
#  ('Made for Love', '1926', 7.0, 21),
#  ('The Magician', '1926', 6.8, 490),
#  ('Manon Lescaut', '1926', 6.4, 39),
#  ('Mare Nostrum', '1926', 7.0, 295),
#  ('Mother', '1926', 7.7, 2182),
#  ("The Bear's Wedding", '1925', 6.9, 17),
#  ('Metropolis', '1927', 8.3, 141709),
#  ("Miss Brewster's Millions", '1926', 7.2, 9),
#  ('Money to Burn', '1926', 7.4, 7),
#  ('Nell Gwyn', '1926', 7.6, 220),
#  ('The New Klondike', '1926', 5.5, 11),
#  ('The Night Patrol', '1926', 6.6, 5),
#  ('North Star', '1925', 6.0, 16),
#  ('Obey the Law', '1926', 6.9, 10),
#  ("Officer '444'", '1926', 5.5, 24),
#  ('Old Ironsides', '1926', 7.0, 139),
#  ('Old Loves and New', '1926', 4.2, 8),
#  ('One Minute to Play', '1926', 7.5, 11),
#  ('The Only Way', '1925', 5.8, 12),
#  ('Padlocked', '1926', 6.5, 6),
#  ('The Palace of Pleasure', '1926', 4.7, 9),
#  ('Paris', '1926', 2.6, 90),
#  ('Paris at Midnight', '1926', 5.3, 21),
#  ('Po zakonu', '1926', 7.8, 779),
#  ('The Quarterback', '1926', 7.5, 8),
#  ("Ranson's Folly", '1926', 4.8, 20),
#  ('The Road to Glory', '1926', 7.1, 29),
#  ('The Road to Mandalay', '1926', 6.7, 135),
#  ('The Runaway Express', '1926', 4.1, 9),
#  ('The Scarlet Letter', '1926', 7.8, 1391),
#  ('Sea Horses', '1926', 5.8, 5),
#  ('The Sea Wolf', '1926', 2.1, 9),
#  ('The Shamrock Handicap', '1926', 5.9, 112),
#  ('Shipwrecked', '1926', 6.9, 8),
#  ('The Show-Off', '1926', 6.9, 236),
#  ('Silence', '1926', 5.3, 9),
#  ('The Silent Flyer', '1926', 2.4, 11),
#  ('The Son of the Sheik', '1926', 7.3, 1660),
#  ('The Sorrows of Satan', '1926', 7.2, 178),
#  ('Spangles', '1926', 7.4, 7),
#  ('Sparrows', '1926', 7.4, 1089),
#  ('The Still Alarm', '1926', 6.1, 9),
#  ('The Stolen Ranch', '1926', 6.1, 35),
#  ('The Man Who Cheated Life', '1926', 7.1, 509),
#  ('Tartuffe', '1925', 7.3, 1701),
#  ('The Temptress', '1926', 7.1, 988),
#  ('Torrent', '1926', 7.1, 647),
#  ('Twinkletoes', '1926', 7.2, 43),
#  ('Children of No Importance', '1926', 7.0, 39),
#  ('The Unknown Soldier', '1926', 7.0, 8),
#  ('Upstage', '1926', 6.9, 59),
#  ('Volcano', '1926', 7.0, 7),
#  ('The Volga Boatman', '1926', 6.7, 104),
#  ('West Point', '1927', 7.7, 1653),
#  ('What Price Glory', '1926', 7.2, 327),
#  ('The Wild Horse Stampede', '1926', 6.4, 12),
#  ('The Winner', '1926', 2.7, 11),
#  ('The Winning of Barbara Worth', '1926', 7.5, 581),
#  ('A Woman of the Sea', '1926', 6.7, 35),
#  ('You Never Know Women', '1926', 6.8, 41),
#  ('Young April', '1926', 7.5, 27),
#  ('Almost Human', '1927', 7.1, 328),
#  ('A Daughter of Destiny', '1928', 6.2, 253),
#  ('Am Rande der Welt', '1927', 6.0, 45),
#  ('The American Beauty', '1927', 7.0, 44),
#  ('Annie Laurie', '1927', 7.6, 343),
#  ('Women of Ryazan', '1927', 7.2, 171),
#  ("Back to God's Country", '1927', 4.6, 10),
#  ('Back to Liberty', '1927', 1.0, 7),
#  ('Barbed Wire', '1927', 7.2, 169),
#  ('The Beloved Rogue', '1927', 7.5, 669),
#  ('Bitter Apples', '1927', 7.1, 14),
#  ('The Blood Ship', '1927', 7.4, 5),
#  ('Broadway Nights', '1927', 5.5, 17),
#  ('Camille', '1926', 6.4, 18),
#  ('Captain Salvation', '1927', 6.9, 221),
#  ('The Loves of Casanova', '1927', 7.0, 161),
#  ('Chain Lightning', '1927', 4.9, 12),
#  ('Man from the Restaurant', '1927', 7.0, 88),
#  ('Chicago', '1927', 7.3, 324),
#  ('Children of Divorce', '1927', 6.8, 152),
#  ('The Claw', '1927', 6.9, 13),
#  ('College', '1927', 7.1, 3920),
#  ('Confetti', '1928', 6.2, 5),
#  ('The Desert of the Lost', '1927', 6.4, 14),
#  ('The Devil Dancer', '1927', 5.1, 25),
#  ('The Girl with the Hat Box', '1927', 7.4, 536),
#  ('The Dove', '1927', 6.4, 42),
#  ('When Boys Leave Home', '1927', 6.2, 1825),
#  ('Dress Parade', '1927', 7.3, 82),
#  ('A Modern Du Barry', '1927', 4.5, 11),
#  ('East Side, West Side', '1927', 7.0, 64),
#  ...]

# %%
sorted_genre_to_movie_rating_pair = defaultdict(list)
for k,v in genre_to_movie_rating_pair.items():
    sorted_genre_to_movie_rating_pair[k] = sorted(v, key=lambda x: x[3], reverse=True)

# %%
json.dump(sorted_genre_to_movie_rating_pair, open("sorted_movies_for_genres.json",'w'))

# %%
tmp = json.load(open("sorted_movies_for_genres.json"))
tmp['Drama']
# Out:
# [['The Shawshank Redemption', '1994', 9.3, 2076280],
#  ['The Dark Knight', '2008', 9.0, 2041796],
#  ['Fight Club', '1999', 8.8, 1661190],
#  ['Pulp Fiction', '1994', 8.9, 1623641],
#  ['Forrest Gump', '1994', 8.8, 1591976],
#  ['The Lord of the Rings: The Fellowship of the Ring', '2001', 8.8, 1494406],
#  ['The Lord of the Rings: The Return of the King', '2003', 8.9, 1477860],
#  ['The Godfather', '1972', 9.2, 1424583],
#  ['The Lord of the Rings: The Two Towers', '2002', 8.7, 1336572],
#  ['Interstellar', '2014', 8.6, 1279823],
#  ['Gladiator', '2000', 8.5, 1200210],
#  ['Django Unchained', '2012', 8.4, 1197937],
#  ['Inglourious Basterds', '2009', 8.3, 1107890],
#  ['Saving Private Ryan', '1998', 8.6, 1098137],
#  ["Schindler's List", '1993', 8.9, 1076017],
#  ['The Departed', '2006', 8.5, 1065571],
#  ['The Prestige', '2006', 8.5, 1054443],
#  ['The Wolf of Wall Street', '2013', 8.2, 1023536],
#  ['The Green Mile', '1999', 8.6, 1002825],
#  ['The Godfather: Part II', '1974', 9.0, 988765],
#  ['American Beauty', '1999', 8.4, 983109],
#  ['Titanic', '1997', 7.8, 947852],
#  ['V for Vendetta', '2005', 8.2, 945757],
#  ['American History X', '1998', 8.5, 943232],
#  ['Léon: The Professional', '1994', 8.6, 914941],
#  ['Braveheart', '1995', 8.4, 884474],
#  ['The Sixth Sense', '1999', 8.1, 838324],
#  ['The Truman Show', '1998', 8.1, 831219],
#  ['The Lion King', '1994', 8.5, 824813],
#  ["One Flew Over the Cuckoo's Nest", '1975', 8.7, 823546],
#  ['Eternal Sunshine of the Spotless Mind', '2004', 8.3, 817815],
#  ['The Shining', '1980', 8.4, 772756],
#  ['A Beautiful Mind', '2001', 8.2, 764491],
#  ['No Country for Old Men', '2007', 8.1, 760679],
#  ['Good Will Hunting', '1997', 8.3, 759026],
#  ['Gone Girl', '2014', 8.1, 754147],
#  ['Slumdog Millionaire', '2008', 8.0, 742963],
#  ['Catch Me If You Can', '2002', 8.1, 710629],
#  ['Gravity', '2013', 7.7, 704294],
#  ['Requiem for a Dream', '2000', 8.3, 694307],
#  ['Donnie Darko', '2001', 8.1, 693537],
#  ['Harry Potter and the Deathly Hallows: Part 2', '2011', 8.1, 685347],
#  ['A Clockwork Orange', '1971', 8.3, 682718],
#  ['The Martian', '2015', 8.0, 672069],
#  ['The Intouchables', '2011', 8.5, 667766],
#  ['Gran Torino', '2008', 8.1, 665621],
#  ['Scarface', '1983', 8.3, 658219],
#  ['Black Swan', '2010', 8.0, 644606],
#  ['City of God', '2002', 8.6, 638593],
#  ['The Pianist', '2002', 8.5, 634962],
#  ['Taxi Driver', '1976', 8.3, 630379],
#  ['I Am Legend', '2007', 7.2, 629854],
#  ['Silver Linings Playbook', '2012', 7.7, 618195],
#  ['The Imitation Game', '2014', 8.0, 614397],
#  ['Whiplash', '2014', 8.5, 606744],
#  ['Full Metal Jacket', '1987', 8.3, 603406],
#  ["The King's Speech", '2010', 8.0, 589890],
#  ['12 Angry Men', '1957', 8.9, 586744],
#  ['Million Dollar Baby', '2004', 8.1, 582522],
#  ['12 Years a Slave', '2013', 8.1, 572285],
#  ["Pan's Labyrinth", '2006', 8.2, 568252],
#  ['The Social Network', '2010', 7.7, 565357],
#  ['Logan', '2017', 8.1, 547918],
#  ['Life Is Beautiful', '1997', 8.6, 546366],
#  ['Apocalypse Now', '1979', 8.5, 543177],
#  ['The Curious Case of Benjamin Button', '2008', 7.8, 535770],
#  ['Argo', '2012', 7.7, 531736],
#  ['Life of Pi', '2012', 7.9, 531261],
#  ['Into the Wild', '2007', 8.1, 521140],
#  ['Prisoners', '2013', 8.1, 520963],
#  ['Drive', '2011', 7.8, 518078],
#  ['Birdman or (The Unexpected Virtue of Ignorance)', '2014', 7.7, 514410],
#  ['Arrival', '2016', 7.9, 507333],
#  ['Jaws', '1975', 8.0, 506284],
#  ['Looper', '2012', 7.4, 497584],
#  ['L.A. Confidential', '1997', 8.3, 489800],
#  ['Casablanca', '1942', 8.5, 471918],
#  ['The Notebook', '2004', 7.9, 471050],
#  ['Rise of the Planet of the Apes', '2011', 7.6, 470411],
#  ['Cast Away', '2000', 7.8, 469546],
#  ['Rocky', '1976', 8.1, 468719],
#  ['Juno', '2007', 7.5, 463972],
#  ['Her', '2013', 8.0, 462175],
#  ['I, Robot', '2004', 7.1, 460908],
#  ['Blood Diamond', '2006', 8.0, 460254],
#  ['There Will Be Blood', '2007', 8.2, 459897],
#  ['Dunkirk', '2017', 7.9, 458679],
#  ['Oldboy', '2003', 8.4, 453778],
#  ['Watchmen', '2009', 7.6, 451788],
#  ['Source Code', '2011', 7.5, 449523],
#  ['Troy', '2004', 7.2, 448904],
#  ['Rain Man', '1988', 8.0, 438957],
#  ['500 Days of Summer', '2009', 7.7, 438451],
#  ['Crazy, Stupid, Love.', '2011', 7.4, 434747],
#  ['La La Land', '2016', 8.0, 429500],
#  ['The Great Gatsby', '2013', 7.3, 429190],
#  ['The Hateful Eight', '2015', 7.8, 428161],
#  ['Children of Men', '2006', 7.9, 427670],
#  ['American Psycho', '2000', 7.6, 427589],
#  ['The Perks of Being a Wallflower', '2012', 8.0, 420352],
#  ['Ex Machina', '2014', 7.7, 419828],
#  ['The Butterfly Effect', '2004', 7.7, 418992],
#  ['American Hustle', '2013', 7.2, 416084],
#  ['Casino', '1995', 8.2, 410874],
#  ['Hancock', '2008', 6.4, 408904],
#  ['Little Miss Sunshine', '2006', 7.8, 407568],
#  ['The Pursuit of Happyness', '2006', 8.0, 402740],
#  ['Warrior', '2011', 8.2, 401118],
#  ['Nightcrawler', '2014', 7.9, 400425],
#  ['Dallas Buyers Club', '2013', 8.0, 399849],
#  ['Crash', '2004', 7.8, 399323],
#  ['American Sniper', '2014', 7.3, 399062],
#  ['Elysium', '2013', 6.6, 393288],
#  ['Twilight', '2008', 5.2, 391903],
#  ['The Hurt Locker', '2008', 7.6, 390010],
#  ['The Help', '2011', 8.1, 389912],
#  ['Rush', '2013', 8.1, 388779],
#  ['Big Fish', '2003', 8.0, 388435],
#  ['Dawn of the Planet of the Apes', '2014', 7.6, 387626],
#  ['Zodiac', '2007', 7.7, 387332],
#  ['Mystic River', '2003', 8.0, 386666],
#  ['The Girl with the Dragon Tattoo', '2011', 7.8, 385604],
#  ['Captain Phillips', '2013', 7.8, 384977],
#  ['Love Actually', '2003', 7.6, 384336],
#  ['Fury', '2014', 7.6, 378983],
#  ['Lost in Translation', '2003', 7.8, 372142],
#  ['Blade Runner 2049', '2017', 8.0, 370474],
#  ['Gangs of New York', '2002', 7.5, 369321],
#  ['The Last Samurai', '2003', 7.7, 367975],
#  ['American Gangster', '2007', 7.8, 364806],
#  ['King Kong', '2005', 7.2, 364370],
#  ['The Terminal', '2004', 7.3, 363283],
#  ['Hacksaw Ridge', '2016', 8.1, 360895],
#  ['Spotlight', '2015', 8.1, 360685],
#  ['Citizen Kane', '1941', 8.3, 360359],
#  ['In Bruges', '2008', 7.9, 359425],
#  ['The Theory of Everything', '2014', 7.7, 357916],
#  ['Baby Driver', '2017', 7.6, 355344],
#  ['Training Day', '2001', 7.7, 354651],
#  ["It's a Wonderful Life", '1946', 8.6, 353389],
#  ['Platoon', '1986', 8.1, 349113],
#  ['Unbreakable', '2000', 7.3, 345480],
#  ['In Time', '2011', 6.7, 344265],
#  ['Bruce Almighty', '2003', 6.7, 344260],
#  ['28 Days Later...', '2002', 7.6, 343607],
#  ['Black Hawk Down', '2001', 7.7, 337552],
#  ['The Devil Wears Prada', '2006', 6.9, 337174],
#  ['The Illusionist', '2006', 7.6, 335577],
#  ['Three Billboards Outside Ebbing, Missouri', '2017', 8.2, 335333],
#  ['Collateral', '2004', 7.5, 333856],
#  ['Amadeus', '1984', 8.3, 333609],
#  ['Stand by Me', '1986', 8.1, 331330],
#  ['Knocked Up', '2007', 7.0, 330350],
#  ['The Machinist', '2004', 7.7, 328043],
#  ['Easy A', '2010', 7.1, 328024],
#  ['Bohemian Rhapsody', '2018', 8.1, 325579],
#  ['Cloud Atlas', '2012', 7.4, 325083],
#  ['Sicario', '2015', 7.6, 325023],
#  ['Moneyball', '2011', 7.6, 324307],
#  ['127 Hours', '2010', 7.6, 321762],
#  ['Sweeney Todd: The Demon Barber of Fleet Street', '2007', 7.4, 320879],
#  ['The Town', '2010', 7.6, 320709],
#  ['The Lives of Others', '2006', 8.4, 319732],
#  ['The Breakfast Club', '1985', 7.9, 316335],
#  ['The Fighter', '2010', 7.8, 314890],
#  ['Signs', '2002', 6.7, 314824],
#  ['Boyhood', '2014', 7.9, 314147],
#  ['The Game', '1997', 7.8, 312847],
#  ['The Fault in Our Stars', '2014', 7.7, 312486],
#  ['Inside Man', '2006', 7.6, 311983],
#  ['Room', '2015', 8.2, 311935],
#  ['Hotel Rwanda', '2004', 8.1, 311639],
#  ['Moon', '2009', 7.9, 310223],
#  ['Passengers', '2016', 7.0, 306879],
#  ['The Aviator', '2004', 7.5, 306023],
#  ['Man on Fire', '2004', 7.7, 305857],
#  ['The Big Short', '2015', 7.8, 305793],
#  ['Downfall', '2004', 8.2, 302460],
#  ['50 First Dates', '2004', 6.8, 302264],
#  ['The Shape of Water', '2017', 7.3, 301369],
#  ['Flight', '2012', 7.3, 301286],
#  ["The Devil's Advocate", '1997', 7.5, 300027],
#  ['Up in the Air', '2009', 7.4, 299670],
#  ['50/50', '2011', 7.7, 299127],
#  ['Brokeback Mountain', '2005', 7.7, 297727],
#  ['3 Idiots', '2009', 8.4, 295911],
#  ['Equilibrium', '2002', 7.5, 294690],
#  ['A Quiet Place', '2018', 7.6, 294133],
#  ['Pearl Harbor', '2001', 6.1, 291750],
#  ['Shooter', '2007', 7.2, 290448],
#  ['Moonrise Kingdom', '2012', 7.8, 289926],
#  ['Mulholland Dr.', '2001', 8.0, 288992],
#  ['Lucky Number Slevin', '2006', 7.8, 287573],
#  ['Being John Malkovich', '1999', 7.8, 287571],
#  ['Burn After Reading', '2008', 7.0, 286056],
#  ['Raging Bull', '1980', 8.2, 285349],
#  ['Les Misérables', '2012', 7.6, 284096],
#  ['Hugo', '2011', 7.5, 283539],
#  ['Real Steel', '2011', 7.1, 282514],
#  ['The Deer Hunter', '1978', 8.1, 282473],
#  ['True Grit', '2010', 7.6, 282281],
#  ['Click', '2006', 6.4, 281917],
#  ['Seven Samurai', '1954', 8.7, 280505],
#  ['Jackie Brown', '1997', 7.5, 278996],
#  ['Fifty Shades of Grey', '2015', 4.1, 277190],
#  ['Lord of War', '2005', 7.6, 276752],
#  ['The Wrestler', '2008', 7.9, 276319],
#  ['Once Upon a Time in America', '1984', 8.4, 274237],
#  ['The Secret Life of Walter Mitty', '2013', 7.3, 274020],
#  ['A.I. Artificial Intelligence', '2001', 7.1, 272987],
#  ['Interview with the Vampire: The Vampire Chronicles', '1994', 7.6, 272686],
#  ['Babel', '2006', 7.5, 272308],
#  ['The Proposal', '2009', 6.7, 270728],
#  ['Eyes Wide Shut', '1999', 7.4, 270620],
#  ['The Book of Eli', '2010', 6.9, 269499],
#  ['Apocalypto', '2006', 7.8, 269435],
#  ['To Kill a Mockingbird', '1962', 8.3, 269256],
#  ['3:10 to Yuma', '2007', 7.7, 268835],
#  ['Magnolia', '1999', 8.0, 268765],
#  ['10 Things I Hate About You', '1999', 7.3, 267781],
#  ['Seven Pounds', '2008', 7.6, 266920],
#  ['The Blind Side', '2009', 7.7, 265395],
#  ['Chinatown', '1974', 8.2, 264065],
#  ['Gone with the Wind', '1939', 8.2, 262468],
#  ['Bridge of Spies', '2015', 7.6, 261060],
#  ['Public Enemies', '2009', 7.0, 260452],
#  ['Top Gun', '1986', 6.9, 259915],
#  ['Gattaca', '1997', 7.8, 258862],
#  ['10 Cloverfield Lane', '2016', 7.2, 257943],
#  ['Snow White and the Huntsman', '2012', 6.1, 257711],
#  ['About Time', '2013', 7.8, 257591],
#  ['The Untouchables', '1987', 7.9, 254224],
#  ['Donnie Brasco', '1997', 7.8, 254108],
#  ['As Good as It Gets', '1997', 7.7, 252754],
#  ['Insomnia', '2002', 7.2, 252312],
#  ['Law Abiding Citizen', '2009', 7.4, 251094],
#  ['Moulin Rouge!', '2001', 7.6, 250925],
#  ['Zero Dark Thirty', '2012', 7.4, 249395],
#  ['Kingdom of Heaven', '2005', 7.2, 249011],
#  ['The Twilight Saga: New Moon', '2009', 4.7, 247296],
#  ['Forgetting Sarah Marshall', '2008', 7.2, 246696],
#  ['Lone Survivor', '2013', 7.5, 245165],
#  ['The Royal Tenenbaums', '2001', 7.6, 244689],
#  ['Apollo 13', '1995', 7.6, 244185],
#  ['The Fugitive', '1993', 7.8, 243833],
#  ['Notting Hill', '1999', 7.1, 243337],
#  ['Fear and Loathing in Las Vegas', '1998', 7.7, 241113],
#  ['28 Weeks Later', '2007', 7.0, 240473],
#  ['1408', '2007', 6.8, 240433],
#  ['Lawrence of Arabia', '1962', 8.3, 239576],
#  ['The Jungle Book', '2016', 7.4, 239250],
#  ['The Hunt', '2012', 8.3, 238589],
#  ['Robin Hood', '2010', 6.7, 238393],
#  ['The Graduate', '1967', 8.0, 236676],
#  ['The Patriot', '2000', 7.2, 236311],
#  ['Panic Room', '2002', 6.8, 235991],
#  ['Before Sunrise', '1995', 8.1, 235939],
#  ['Hannibal', '2001', 6.8, 235846],
#  ['A Star Is Born', '2018', 7.8, 234708],
#  ['Contact', '1997', 7.4, 234324],
#  ['Snowpiercer', '2013', 7.1, 233857],
#  ['Almost Famous', '2000', 7.9, 233848],
#  ['Gone Baby Gone', '2007', 7.7, 232456],
#  ['The Accountant', '2016', 7.3, 231097],
#  ['Red Dragon', '2002', 7.2, 230889],
#  ['Pride & Prejudice', '2005', 7.8, 229454],
#  ['Chronicle', '2012', 7.1, 228325],
#  ['Noah', '2014', 5.8, 228170],
#  ['The Grey', '2011', 6.8, 227845],
#  ['Lincoln', '2012', 7.4, 227559],
#  ['Road to Perdition', '2002', 7.7, 227246],
#  ['8 Mile', '2002', 7.1, 227202],
#  ['Atonement', '2007', 7.8, 227126],
#  ['Vicky Cristina Barcelona', '2008', 7.1, 226695],
#  ['The Village', '2004', 6.5, 226526],
#  ['The Place Beyond the Pines', '2012', 7.3, 225480],
#  ['Moonlight', '2016', 7.4, 224308],
#  ['Enemy at the Gates', '2001', 7.6, 223357],
#  ['Predestination', '2014', 7.5, 223353],
#  ['Blow', '2001', 7.6, 222984],
#  ['The Descendants', '2011', 7.3, 222856],
#  ['Annihilation', '2018', 6.9, 222353],
#  ['Corpse Bride', '2005', 7.4, 222278],
#  ['Changeling', '2008', 7.7, 222259],
#  ['Creed', '2015', 7.6, 222042],
#  ["Hachi: A Dog's Tale", '2009', 8.1, 221042],
#  ['Boogie Nights', '1997', 7.9, 218714],
#  ['Mrs. Doubtfire', '1993', 7.0, 218515],
#  ['Perfume: The Story of a Murderer', '2006', 7.5, 218479],
#  ['The Sting', '1973', 8.3, 217487],
#  ['The Reader', '2008', 7.6, 216961],
#  ['Dog Day Afternoon', '1975', 8.0, 216723],
#  ['The Artist', '2011', 7.9, 216351],
#  ['The Fountain', '2006', 7.3, 215587],
#  ['Don Jon', '2013', 6.6, 215231],
#  ['The Twilight Saga: Breaking Dawn - Part 2', '2012', 5.5, 213724],
#  ['Eastern Promises', '2007', 7.6, 213567],
#  ['Lawless', '2012', 7.3, 213134],
#  ['The Bucket List', '2007', 7.4, 213133],
#  ['Valkyrie', '2008', 7.1, 212727],
#  ['21', '2008', 6.8, 212673],
#  ['Chappie', '2015', 6.8, 212436],
#  ['Manchester by the Sea', '2016', 7.8, 212140],
#  ['21 Grams', '2003', 7.7, 212014],
#  ['Walk the Line', '2005', 7.9, 211740],
#  ['The Twilight Saga: Eclipse', '2010', 5.0, 210368],
#  ['End of Watch', '2012', 7.6, 210184],
#  ['A History of Violence', '2005', 7.5, 209979],
#  ['Bird Box', '2018', 6.6, 208023],
#  ['Knowing', '2009', 6.2, 207995],
#  ['Das Boot', '1981', 8.4, 207350],
#  ['The Twilight Saga: Breaking Dawn - Part 1', '2011', 4.9, 207095],
#  ['The Beach', '2000', 6.6, 206963],
#  ['The Ides of March', '2011', 7.1, 206861],
#  ['Disturbia', '2007', 6.9, 206626],
#  ['The Road', '2009', 7.3, 206610],
#  ['Before Sunset', '2004', 8.1, 206268],
#  ['Stranger Than Fiction', '2006', 7.6, 206091],
#  ['Gandhi', '1982', 8.1, 206079],
#  ['Amores Perros', '2000', 8.1, 205901],
#  ['Thank You for Smoking', '2005', 7.6, 205454],
#  ['Philadelphia', '1993', 7.7, 205281],
#  ["Bridget Jones's Diary", '2001', 6.7, 205259],
#  ['The Great Escape', '1963', 8.2, 203629],
#  ['Transcendence', '2014', 6.3, 203519],
#  ['Nocturnal Animals', '2016', 7.5, 202944],
#  ['Garden State', '2004', 7.5, 200833],
#  ['Contagion', '2011', 6.6, 200665],
#  ['Shakespeare in Love', '1998', 7.1, 200236],
#  ['Ben-Hur', '1959', 8.1, 200179],
#  ['Sully', '2016', 7.5, 200129],
#  ['The Passion of the Christ', '2004', 7.2, 200036],
#  ['Natural Born Killers', '1994', 7.3, 198987],
#  ['The Elephant Man', '1980', 8.2, 198956],
#  ['Cinema Paradiso', '1988', 8.5, 198807],
#  ['War for the Planet of the Apes', '2017', 7.5, 198569],
#  ['Body of Lies', '2008', 7.1, 198459],
#  ['Southpaw', '2015', 7.4, 198447],
#  ['Munich', '2005', 7.6, 197868],
#  ['Dogma', '1999', 7.3, 197717],
#  ['The Girl with the Dragon Tattoo', '2009', 7.8, 197069],
#  ["What's Eating Gilbert Grape", '1993', 7.8, 196333],
#  ['The Greatest Showman', '2017', 7.6, 195931],
#  ['Mr. Nobody', '2009', 7.8, 195781],
#  ['The Lincoln Lawyer', '2011', 7.3, 195301],
#  ['Ip Man', '2008', 8.0, 195191],
#  ['Gangster Squad', '2013', 6.7, 194735],
#  ['Let the Right One In', '2008', 7.9, 194219],
#  ['Meet Joe Black', '1998', 7.2, 194084],
#  ['A Separation', '2011', 8.3, 194024],
#  ['Grave of the Fireflies', '1988', 8.5, 193228],
#  ['The Conjuring 2', '2016', 7.4, 191375],
#  ['San Andreas', '2015', 6.1, 190969],
#  ['P.S. I Love You', '2007', 7.1, 190742],
#  ['White House Down', '2013', 6.4, 190650],
#  ['Finding Neverland', '2004', 7.7, 190435],
#  ['Cube', '1997', 7.3, 190409],
#  ['Match Point', '2005', 7.6, 190351],
#  ['The Girl Next Door', '2004', 6.7, 189831],
#  ['Closer', '2004', 7.3, 189718],
#  ['Rocky Balboa', '2006', 7.2, 189327],
#  ['Master and Commander: The Far Side of the World', '2003', 7.4, 188618],
#  ['Modern Times', '1936', 8.5, 187728],
#  ['True Romance', '1993', 7.9, 187417],
#  ['A Walk to Remember', '2002', 7.4, 187236],
#  ['Butch Cassidy and the Sundance Kid', '1969', 8.1, 186017],
#  ['Traffic', '2000', 7.6, 185615],
#  ['The Bridge on the River Kwai', '1957', 8.2, 185018],
#  ['Big Daddy', '1999', 6.4, 184202],
#  ['Remember the Titans', '2000', 7.8, 183497],
#  ['The Sound of Music', '1965', 8.0, 181438],
#  ['The Lobster', '2015', 7.1, 179813],
#  ['Lion', '2016', 8.1, 179422],
#  ['Green Book', '2018', 8.3, 179219],
#  ['Blue Jasmine', '2013', 7.3, 178528],
#  ['Run Lola Run', '1998', 7.7, 178509],
#  ['Hanna', '2011', 6.8, 178190],
#  ['The Great Dictator', '1940', 8.5, 178173],
#  ['Coraline', '2009', 7.7, 177456],
#  ['Big', '1988', 7.3, 177377],
#  ['Revolutionary Road', '2008', 7.3, 177194],
#  ['Sunset Boulevard', '1950', 8.4, 177039],
#  ["You've Got Mail", '1998', 6.6, 176374],
#  ['The Impossible', '2012', 7.6, 176369],
#  ['Murder on the Orient Express', '2017', 6.5, 175963],
#  ['Brazil', '1985', 8.0, 174460],
#  ['Tinker Tailor Soldier Spy', '2011', 7.1, 174099],
#  ['Ghost in the Shell', '2017', 6.4, 173999],
#  ['Hell or High Water', '2016', 7.6, 173947],
#  ['Lady Bird', '2017', 7.4, 173882],
#  ['Dirty Dancing', '1987', 6.9, 173604],
#  ['The Vow', '2012', 6.8, 172597],
#  ['Chef', '2014', 7.3, 171849],
#  ['The Secret in Their Eyes', '2009', 8.2, 171560],
#  ['Rocky II', '1979', 7.2, 171410],
#  ['Shame', '2011', 7.2, 170550],
#  ['Me Before You', '2016', 7.4, 170168],
#  ['The Babadook', '2014', 6.8, 169360],
#  ['Blue Valentine', '2010', 7.4, 169169],
#  ['Secret Window', '2004', 6.6, 169053],
#  ['Sideways', '2004', 7.5, 169050],
#  ['Hidden Figures', '2016', 7.8, 168883],
#  ['The Boy in the Striped Pajamas', '2008', 7.8, 168816],
#  ["Rosemary's Baby", '1968', 8.0, 168545],
#  ['Cruel Intentions', '1999', 6.8, 168268],
#  ['Fracture', '2007', 7.2, 168097],
#  ['Side Effects', '2013', 7.1, 167804],
#  ['Rocky IV', '1985', 6.8, 167783],
#  ['Chocolat', '2000', 7.3, 167681],
#  ['The Next Three Days', '2010', 7.4, 166657],
#  ['Love & Other Drugs', '2010', 6.7, 166631],
#  ['K-PAX', '2001', 7.4, 166603],
#  ['King Arthur: Legend of the Sword', '2017', 6.8, 166573],
#  ['Air Force One', '1997', 6.5, 166367],
#  ['Close Encounters of the Third Kind', '1977', 7.7, 166266],
#  ['17 Again', '2009', 6.4, 166165],
#  ['Cinderella Man', '2005', 8.0, 165841],
#  ['Wind River', '2017', 7.7, 165773],
#  ['The Last King of Scotland', '2006', 7.7, 164717],
#  ['The Woman in Black', '2012', 6.4, 164683],
#  ['The Darjeeling Limited', '2007', 7.2, 164470],
#  ['Adaptation.', '2002', 7.7, 164427],
#  ['The Promise', '2016', 6.1, 164314],
#  ['Straight Outta Compton', '2015', 7.9, 164164],
#  ['Dracula Untold', '2014', 6.3, 163736],
#  ['25th Hour', '2002', 7.7, 162285],
#  ['The Judge', '2014', 7.4, 161479],
#  ['Blue Velvet', '1986', 7.8, 161478],
#  ['Jarhead', '2005', 7.0, 161332],
#  ['The Talented Mr. Ripley', '1999', 7.4, 160365],
#  ['About a Boy', '2002', 7.1, 160030],
#  ['Pi', '1998', 7.4, 160008],
#  ['The Thin Red Line', '1998', 7.6, 159739],
#  ['The Man from Earth', '2007', 7.9, 159480],
#  ['Battle Royale', '2000', 7.7, 158562],
#  ['Erin Brockovich', '2000', 7.3, 157981],
#  ['High Fidelity', '2000', 7.5, 157853],
#  ['Captain Fantastic', '2016', 7.9, 157138],
#  ['Ed Wood', '1994', 7.9, 156892],
#  ['The Karate Kid', '1984', 7.2, 156730],
#  ['Rushmore', '1998', 7.7, 156533],
#  ['The Assassination of Jesse James by the Coward Robert Ford',
#   '2007',
#   7.5,
#   156264],
#  ['Mud', '2012', 7.4, 156125],
#  ['The Tree of Life', '2011', 6.8, 155540],
#  ['Rocky III', '1982', 6.8, 155156],
#  ['Milk', '2008', 7.6, 155094],
#  ['Black Mass', '2015', 6.9, 154967],
#  ['The Day the Earth Stood Still', '2008', 5.5, 154944],
#  ['Falling Down', '1993', 7.6, 154886],
#  ['The Crow', '1994', 7.6, 154393],
#  ['Paths of Glory', '1957', 8.4, 154260],
#  ['The Birds', '1963', 7.7, 153883],
#  ['Hitman', '2007', 6.3, 153488],
#  ['Mother!', '2017', 6.6, 153154],
#  ['Layer Cake', '2004', 7.3, 152815],
#  ['Melancholia', '2011', 7.2, 152496],
#  ['Immortals', '2011', 6.0, 152366],
#  ['War Dogs', '2016', 7.1, 152280],
#  ['King Arthur', '2004', 6.3, 151395],
#  ['Deep Impact', '1998', 6.2, 150747],
#  ["Breakfast at Tiffany's", '1961', 7.7, 150453],
#  ['The Abyss', '1989', 7.6, 150427],
#  ['Call Me by Your Name', '2017', 7.9, 150195],
#  ['Exodus: Gods and Kings', '2014', 6.0, 150117],
#  ['Mary and Max', '2009', 8.1, 149853],
#  ['Wild Tales', '2014', 8.1, 149194],
#  ['The Girl on the Train', '2016', 6.5, 149159],
#  ["He's Just Not That Into You", '2009', 6.4, 149080],
#  ['The Insider', '1999', 7.9, 149049],
#  ['The Legend of Tarzan', '2016', 6.3, 148760],
#  ['Michael Clayton', '2007', 7.3, 148292],
#  ['The Ghost Writer', '2010', 7.2, 147804],
#  ['Cool Hand Luke', '1967', 8.1, 147523],
#  ['Superman', '1978', 7.4, 147020],
#  ['The Perfect Storm', '2000', 6.4, 146411],
#  ['Girl, Interrupted', '1999', 7.4, 146283],
#  ['Hard Candy', '2005', 7.1, 146254],
#  ['Adventureland', '2009', 6.8, 146109],
#  ['Letters from Iwo Jima', '2006', 7.9, 145855],
#  ['The Danish Girl', '2015', 7.1, 145601],
#  ['The Man in the Iron Mask', '1998', 6.5, 145391],
#  ['The Karate Kid', '2010', 6.2, 145255],
#  ['Definitely, Maybe', '2008', 7.2, 145250],
#  ['The Lovely Bones', '2009', 6.7, 144886],
#  ['City Lights', '1931', 8.5, 144811],
#  ['Hereditary', '2018', 7.3, 144267],
#  ['Sleepless in Seattle', '1993', 6.8, 144002],
#  ['The Fly', '1986', 7.5, 143633],
#  ['Flightplan', '2005', 6.3, 142902],
#  ['The Seventh Seal', '1957', 8.2, 142290],
#  ['The Apartment', '1960', 8.3, 141857],
#  ['Metropolis', '1927', 8.3, 141709],
#  ['The Punisher', '2004', 6.5, 141682],
#  ['The Bone Collector', '1999', 6.7, 141108],
#  ['Cinderella', '2015', 6.9, 140930],
#  ['In the Name of the Father', '1993', 8.1, 140317],
#  ['Invictus', '2009', 7.3, 140279],
#  ['Saving Mr. Banks', '2013', 7.5, 139680],
#  ["Miss Peregrine's Home for Peculiar Children", '2016', 6.7, 139401],
#  ['Fantastic Four', '2015', 4.3, 139032],
#  ['Like Stars on Earth', '2007', 8.4, 138935],
#  ['Buried', '2010', 7.0, 138586],
#  ['Vantage Point', '2008', 6.6, 138395],
#  ['I, Tonya', '2017', 7.5, 138084],
#  ['Akira', '1988', 8.1, 137859],
#  ['The Age of Adaline', '2015', 7.2, 137785],
#  ['Steve Jobs', '2015', 7.2, 137739],
#  ['Legend', '2015', 7.0, 137568],
#  ['The Orphanage', '2007', 7.5, 136937],
#  ['BlacKkKlansman', '2018', 7.5, 136305],
#  ['Mr. Brooks', '2007', 7.3, 136131],
#  ['War Horse', '2011', 7.2, 135462],
#  ['Marley & Me', '2008', 7.1, 135312],
#  ['I Am Sam', '2001', 7.6, 135236],
#  ['47 Ronin', '2013', 6.3, 134681],
#  ['Bowling for Columbine', '2002', 8.0, 134548],
#  ['Darkest Hour', '2017', 7.4, 134002],
#  ['Wall Street', '1987', 7.4, 133982],
#  ['Rounders', '1998', 7.3, 133933],
#  ['The Virgin Suicides', '1999', 7.2, 133676],
#  ['Red Sparrow', '2018', 6.6, 133441],
#  ['Green Street Hooligans', '2005', 7.5, 133201],
#  ['The Spectacular Now', '2013', 7.1, 132886],
#  ['Rashomon', '1950', 8.3, 132580],
#  ['Legends of the Fall', '1994', 7.5, 132257],
#  ["The Time Traveler's Wife", '2009', 7.1, 132077],
#  ['The Way Way Back', '2013', 7.4, 132059],
#  ['Deepwater Horizon', '2016', 7.1, 131964],
#  ['Punch-Drunk Love', '2002', 7.3, 131634],
#  ['Cold Mountain', '2003', 7.2, 131623],
#  ['The Drop', '2014', 7.1, 131440],
#  ['Memoirs of a Geisha', '2005', 7.4, 131139],
#  ['Barry Lyndon', '1975', 8.1, 131127],
#  ["Smokin' Aces", '2006', 6.7, 131092],
#  ['Lars and the Real Girl', '2007', 7.3, 130733],
#  ['Bridge to Terabithia', '2007', 7.2, 130728],
#  ['The Master', '2012', 7.1, 130224],
#  ['Network', '1976', 8.1, 130104],
#  ['Defiance', '2008', 7.2, 129717],
#  ['Never Let Me Go', '2010', 7.1, 129528],
#  ['Your Name.', '2016', 8.4, 129388],
#  ['Unbroken', '2014', 7.2, 129188],
#  ['The Lake House', '2006', 6.8, 128959],
#  ['Begin Again', '2013', 7.4, 128829],
#  ['Remember Me', '2010', 7.1, 128714],
#  ['Good Bye Lenin!', '2003', 7.7, 128646],
#  ['On the Waterfront', '1954', 8.2, 127907],
#  ['Dear John', '2010', 6.3, 127705],
#  ['One Day', '2011', 7.0, 127300],
#  ["Winter's Bone", '2010', 7.2, 127222],
#  ['Ray', '2004', 7.7, 126979],
#  ['Bad Santa', '2003', 7.1, 126925],
#  ['State of Play', '2009', 7.1, 126550],
#  ['Castle in the Sky', '1986', 8.1, 126521],
#  ['We Bought a Zoo', '2011', 7.1, 126178],
#  ['Double Indemnity', '1944', 8.3, 126106],
#  ['Four Weddings and a Funeral', '1994', 7.1, 125769],
#  ['Dogville', '2003', 8.0, 125606],
#  ['Spring Breakers', '2012', 5.3, 125606],
#  ['Foxcatcher', '2014', 7.0, 125424],
#  ['Bicycle Thieves', '1948', 8.3, 125328],
#  ["It's Kind of a Funny Story", '2010', 7.1, 125124],
#  ['Chasing Amy', '1997', 7.3, 124994],
#  ['The Constant Gardener', '2005', 7.4, 124946],
#  ['Four Brothers', '2005', 6.9, 124707],
#  ['Carrie', '2013', 5.9, 124637],
#  ['Payback', '1999', 7.1, 124227],
#  ['Allied', '2016', 7.1, 124107],
#  ['Monster', '2003', 7.3, 123966],
#  ['Magic Mike', '2012', 6.1, 123348],
#  ['Blue Is the Warmest Color', '2013', 7.8, 123192],
#  ['Inside Llewyn Davis', '2013', 7.5, 122874],
#  ['Into the Woods', '2014', 6.0, 122830],
#  ['The Gift', '2015', 7.1, 122792],
#  ['An Education', '2009', 7.3, 122764],
#  ['Incendies', '2010', 8.3, 122565],
#  ['We Need to Talk About Kevin', '2011', 7.5, 122563],
#  ['The Skin I Live In', '2011', 7.6, 122549],
#  ['Fahrenheit 9/11', '2004', 7.5, 122085],
#  ['Before Midnight', '2013', 7.9, 122054],
#  ['Green Zone', '2010', 6.8, 121749],
#  ['The Negotiator', '1998', 7.3, 121629],
#  ['16 Blocks', '2006', 6.6, 121407],
#  ['Trainwreck', '2015', 6.2, 121160],
#  ['Manhattan', '1979', 8.0, 121077],
#  ['A Serious Man', '2009', 7.1, 121016],
#  ['Last Vegas', '2013', 6.6, 120916],
#  ['Shallow Hal', '2001', 5.9, 120548],
#  ['The Kids Are All Right', '2010', 7.0, 120326],
#  ['We Were Soldiers', '2002', 7.2, 120325],
#  ['Syriana', '2005', 6.9, 120015],
#  ['Locke', '2013', 7.1, 119753],
#  ['The Count of Monte Cristo', '2002', 7.8, 119617],
#  ['10,000 BC', '2008', 5.1, 119471],
#  ['Dangal', '2016', 8.5, 118985],
#  ['The Book Thief', '2013', 7.6, 118316],
#  ['The NeverEnding Story', '1984', 7.4, 117975],
#  ['Snowden', '2016', 7.3, 117740],
#  ['Matchstick Men', '2003', 7.3, 117621],
#  ['Kramer vs. Kramer', '1979', 7.8, 117599],
#  ['Max Payne', '2008', 5.4, 117234],
#  ['Joy', '2015', 6.6, 117187],
#  ['The Monuments Men', '2014', 6.1, 117059],
#  ['About Schmidt', '2002', 7.2, 116935],
#  ['Bambi', '1942', 7.3, 116808],
#  ["My Best Friend's Wedding", '1997', 6.3, 116604],
#  ['Capote', '2005', 7.4, 116478],
#  ['The Break-Up', '2006', 5.8, 116445],
#  ['Man on the Moon', '1999', 7.4, 116141],
#  ['The Hours', '2002', 7.6, 116126],
#  ['Still Alice', '2014', 7.5, 116010],
#  ['Good Morning, Vietnam', '1987', 7.3, 115731],
#  ['J. Edgar', '2011', 6.6, 115411],
#  ['Savages', '2012', 6.5, 115118],
#  ['John Q', '2002', 7.1, 114708],
#  ['Rope', '1948', 8.0, 114597],
#  ['Billy Elliot', '2000', 7.7, 114263],
#  ['Jack Ryan: Shadow Recruit', '2014', 6.2, 114233],
#  ['Tombstone', '1993', 7.8, 114217],
#  ['Pleasantville', '1998', 7.5, 114135],
#  ['First Man', '2018', 7.4, 113556],
#  ['Australia', '2008', 6.6, 113347],
#  ['Doubt', '2008', 7.5, 113165],
#  ['My Big Fat Greek Wedding', '2002', 6.6, 113146],
#  ['The Score', '2001', 6.8, 112696],
#  ['Spartacus', '1960', 7.9, 112534],
#  ['Hairspray', '2007', 6.7, 112472],
#  ['Life as We Know It', '2010', 6.6, 112347],
#  ['The Kingdom', '2007', 7.0, 112291],
#  ['Papillon', '1973', 8.0, 112200],
#  ['Under the Skin', '2013', 6.3, 112174],
#  ['Seven Years in Tibet', '1997', 7.0, 112056],
#  ['Me and Earl and the Dying Girl', '2015', 7.8, 111716],
#  ['Safety Not Guaranteed', '2012', 7.0, 111463],
#  ['Contraband', '2012', 6.5, 111264],
#  ['Flags of our Fathers', '2006', 7.1, 111166],
#  ['Coach Carter', '2005', 7.3, 111083],
#  ['Carnage', '2011', 7.2, 110840],
#  ['Infernal Affairs', '2002', 8.1, 110579],
#  ['Hail, Caesar!', '2016', 6.3, 110490],
#  ['The Exorcism of Emily Rose', '2005', 6.7, 110410],
#  ['Rebecca', '1940', 8.1, 110097],
#  ['What Lies Beneath', '2000', 6.6, 109877],
#  ['Sex and the City', '2008', 5.6, 109758],
#  ['The Disaster Artist', '2017', 7.4, 109703],
#  ['Wild', '2014', 7.1, 109453],
#  ['Wonder', '2017', 8.0, 109359],
#  ['This Is England', '2006', 7.7, 109286],
#  ['The Phantom of the Opera', '2004', 7.3, 109210],
#  ['The Walk', '2015', 7.3, 109003],
#  ['Funny People', '2009', 6.3, 108672],
#  ['Babe', '1995', 6.8, 108435],
#  ['One Hour Photo', '2002', 6.8, 107695],
#  ['The Parent Trap', '1998', 6.5, 107684],
#  ['The Prince of Egypt', '1998', 7.1, 107679],
#  ['Dumbo', '1941', 7.3, 107002],
#  ['Pay It Forward', '2000', 7.2, 106826],
#  ['If I Stay', '2014', 6.8, 106790],
#  ['Margin Call', '2011', 7.1, 106743],
#  ['Y Tu Mamá También', '2001', 7.7, 106712],
#  ['All About Eve', '1950', 8.3, 106706],
#  ['City of Angels', '1998', 6.7, 106579],
#  ['Let Me In', '2010', 7.1, 106487],
#  ['Ghost World', '2001', 7.4, 106484],
#  ['Any Given Sunday', '1999', 6.9, 106235],
#  ['Irreversible', '2002', 7.4, 106229],
#  ['Tears of the Sun', '2003', 6.6, 106214],
#  ['The Favourite', '2018', 7.6, 106198],
#  ['Nymphomaniac: Vol. I', '2013', 6.9, 105928],
#  ['The Post', '2017', 7.2, 105892],
#  ['Antichrist', '2009', 6.6, 105822],
#  ['The Shallows', '2016', 6.3, 105548],
#  ['Glass', '2019', 6.8, 105529],
#  ['Water for Elephants', '2011', 6.9, 105393],
#  ['The Firm', '1993', 6.8, 105307],
#  ['Empire of the Sun', '1987', 7.8, 105268],
#  ['The Host', '2013', 5.9, 105163],
#  ['Nebraska', '2013', 7.7, 104874],
#  ['Once', '2007', 7.9, 104674],
#  ['In the Mood for Love', '2000', 8.1, 104551],
#  ['A Walk Among the Tombstones', '2014', 6.5, 104533],
#  ['Trance', '2013', 6.9, 104501],
#  ['The Giver', '2014', 6.5, 104443],
#  ['Logan Lucky', '2017', 7.0, 104342],
#  ['Escape from Alcatraz', '1979', 7.6, 104205],
#  ['I Origins', '2014', 7.4, 103892],
#  ['Step Up', '2006', 6.6, 103676],
#  ['The Jacket', '2005', 7.1, 103293],
#  ['The Call', '2013', 6.7, 103108],
#  ["Something's Gotta Give", '2003', 6.7, 102838],
#  ['The Big Sick', '2017', 7.6, 102724],
#  ['13 Hours', '2016', 7.3, 102520],
#  ['Brothers', '2009', 7.1, 102448],
#  ['Anastasia', '1997', 7.1, 102361],
#  ['Street Kings', '2008', 6.8, 102256],
#  ['Hostage', '2005', 6.6, 102090],
#  ["Lee Daniels' The Butler", '2013', 7.2, 102026],
#  ['Roma', '2018', 7.8, 101966],
#  ["Molly's Game", '2017', 7.5, 101887],
#  ['House of Flying Daggers', '2004', 7.6, 101822],
#  ['Bicentennial Man', '1999', 6.9, 101780],
#  ['Seeking a Friend for the End of the World', '2012', 6.7, 101685],
#  ['The Way Back', '2010', 7.3, 101626],
#  ['The Fall', '2006', 7.9, 101310],
#  ['The Life of David Gale', '2003', 7.6, 101232],
#  ['Pirate Radio', '2009', 7.4, 101205],
#  ['Across the Universe', '2007', 7.4, 101184],
#  ['The Treasure of the Sierra Madre', '1948', 8.2, 101061],
#  ['Wild Things', '1998', 6.5, 100742],
#  ['Coyote Ugly', '2000', 5.7, 100509],
#  ['Men of Honor', '2000', 7.2, 100460],
#  ['Little Children', '2006', 7.5, 100237],
#  ["Charlie Wilson's War", '2007', 7.1, 100030],
#  ['The Dreamers', '2003', 7.2, 100007],
#  ['Rang De Basanti', '2006', 8.2, 99772],
#  ['Pompeii', '2014', 5.5, 99748],
#  ['Only God Forgives', '2013', 5.7, 99741],
#  ['Precious', '2009', 7.3, 99681],
#  ['Carol', '2015', 7.2, 99633],
#  ['A Scanner Darkly', '2006', 7.1, 99623],
#  ['The Skeleton Key', '2005', 6.5, 99366],
#  ['Lights Out', '2016', 6.3, 99282],
#  ['Memories of Murder', '2003', 8.1, 99170],
#  ['The Jackal', '1997', 6.4, 99105],
#  ['A Single Man', '2009', 7.6, 98971],
#  ['8½', '1963', 8.1, 98868],
#  ['Bend It Like Beckham', '2002', 6.7, 98853],
#  ['The French Connection', '1971', 7.8, 98802],
#  ['Ran', '1985', 8.2, 98795],
#  ['The Amityville Horror', '2005', 6.0, 98715],
#  ['August Rush', '2007', 7.5, 98668],
#  ['Out of the Furnace', '2013', 6.8, 98555],
#  ['The Diving Bell and the Butterfly', '2007', 8.0, 98195],
#  ['Paycheck', '2003', 6.3, 97770],
#  ['Get the Gringo', '2012', 7.0, 97654],
#  ['Mr. Smith Goes to Washington', '1939', 8.2, 97592],
#  ['The Wolfman', '2010', 5.8, 97432],
#  ['The Queen', '2006', 7.3, 97418],
#  ['Hannibal Rising', '2007', 6.2, 97315],
#  ['The Manchurian Candidate', '2004', 6.6, 97083],
#  ['Stoker', '2013', 6.8, 96985],
#  ["The Man Who Wasn't There", '2001', 7.6, 96917],
#  ['Frost/Nixon', '2008', 7.7, 96782],
#  ['Stalker', '1979', 8.1, 96766],
#  ['The Family Man', '2000', 6.8, 96740],
#  ['Talk to Her', '2002', 8.0, 96652],
#  ['The Sum of All Fears', '2002', 6.4, 96484],
#  ['The Other Boleyn Girl', '2008', 6.7, 96414],
#  ['Serpico', '1973', 7.8, 96344],
#  ['Safe Haven', '2013', 6.7, 96314],
#  ['Where the Wild Things Are', '2009', 6.8, 96166],
#  ['The Founder', '2016', 7.2, 96037],
#  ['Yojimbo', '1961', 8.3, 95883],
#  ['Julie & Julia', '2009', 7.0, 95768],
#  ['The Iron Lady', '2011', 6.4, 95618],
#  ['Bridget Jones: The Edge of Reason', '2004', 6.0, 95337],
#  ['Super Size Me', '2004', 7.2, 95332],
#  ['The X Files', '1998', 7.0, 95270],
#  ['The Best Offer', '2013', 7.8, 95170],
#  ['The Kid', '1921', 8.3, 95102],
#  ['Alpha Dog', '2006', 6.9, 94984],
#  ['Burnt', '2015', 6.6, 94953],
#  ['What Dreams May Come', '1998', 7.0, 94932],
#  ['The Wave', '2008', 7.6, 94678],
#  ['Patch Adams', '1998', 6.8, 94621],
#  ['The Rum Diary', '2011', 6.2, 94513],
#  ['Brick', '2005', 7.4, 94454],
#  ['Behind Enemy Lines', '2001', 6.4, 94367],
#  ['Frequency', '2000', 7.4, 94181],
#  ['The Good Shepherd', '2006', 6.7, 94054],
#  ['The Name of the Rose', '1986', 7.8, 93887],
#  ['Running Scared', '2006', 7.4, 93766],
#  ['The Lucky One', '2012', 6.5, 93740],
#  ['Unleashed', '2005', 7.0, 93668],
#  ['Run All Night', '2015', 6.6, 93578],
#  ['The Basketball Diaries', '1995', 7.3, 93537],
#  ['Dan in Real Life', '2007', 6.8, 93514],
#  ['Faster', '2010', 6.5, 93150],
#  ['Wall Street: Money Never Sleeps', '2010', 6.2, 93136],
#  ['Dancer in the Dark', '2000', 8.0, 93053],
#  ['Sphere', '1998', 6.1, 93020],
#  ['I Saw the Devil', '2010', 7.8, 93005],
#  ['A Dangerous Method', '2011', 6.4, 92838],
#  ['Extremely Loud & Incredibly Close', '2011', 6.9, 92823],
#  ['Just Like Heaven', '2005', 6.7, 92607],
#  ['United 93', '2006', 7.6, 92525],
#  ['Marie Antoinette', '2006', 6.4, 92522],
#  ['Baahubali: The Beginning', '2015', 8.1, 92519],
#  ['Willow', '1988', 7.3, 92478],
#  ['Touch of Evil', '1958', 8.0, 92446],
#  ['The Full Monty', '1997', 7.2, 92258],
#  ['Lagaan: Once Upon a Time in India', '2001', 8.1, 92084],
#  ['Elite Squad', '2007', 8.1, 92049],
#  ['Broken Flowers', '2005', 7.2, 91811],
#  ['Poseidon', '2006', 5.6, 91737],
#  ['The Counselor', '2013', 5.3, 91701],
#  ['The 400 Blows', '1959', 8.1, 91521],
#  ["All the President's Men", '1976', 8.0, 91402],
#  ['The Motorcycle Diaries', '2004', 7.8, 91345],
#  ['A Christmas Carol', '2009', 6.8, 91344],
#  ['A Streetcar Named Desire', '1951', 8.0, 91050],
#  ['Sicario: Day of the Soldado', '2018', 7.1, 90736],
#  ['Searching', '2018', 7.7, 90707],
#  ['Ruby Sparks', '2012', 7.2, 90611],
#  ['Swiss Army Man', '2016', 7.0, 90591],
#  ['Deliverance', '1972', 7.7, 90566],
#  ['Never Back Down', '2008', 6.6, 90402],
#  ['My Name Is Khan', '2010', 8.0, 90401],
#  ['Witness for the Prosecution', '1957', 8.4, 90320],
#  ['The Switch', '2010', 6.1, 90189],
#  ['High Noon', '1952', 8.0, 90059],
#  ['The 5th Wave', '2016', 5.2, 90044],
#  ["Before the Devil Knows You're Dead", '2007', 7.3, 89930],
#  ['Lady in the Water', '2006', 5.6, 89922],
#  ['Good Night, and Good Luck.', '2005', 7.5, 89742],
#  ['Reign Over Me', '2007', 7.5, 89737],
#  ['Midnight Cowboy', '1969', 7.9, 89730],
#  ['Born on the Fourth of July', '1989', 7.2, 89454],
#  ['Primer', '2004', 6.9, 89183],
#  ['St. Vincent', '2014', 7.3, 88993],
#  ['Tootsie', '1982', 7.4, 88859],
#  ['The Gold Rush', '1925', 8.2, 88829],
#  ['Philomena', '2013', 7.6, 88321],
#  ['Enter the Dragon', '1973', 7.7, 88202],
#  ['Easy Rider', '1969', 7.4, 87896],
#  ['The Cider House Rules', '1999', 7.4, 87867],
#  ['A Prophet', '2009', 7.9, 87802],
#  ['The Killing of a Sacred Deer', '2017', 7.0, 87640],
#  ['Patton', '1970', 8.0, 87582],
#  ['Ali', '2001', 6.8, 87494],
#  ['Splice', '2009', 5.7, 87390],
#  ['Black Mirror: Bandersnatch', '2018', 7.3, 87333],
#  ['Colombiana', '2011', 6.4, 87155],
#  ['Paper Towns', '2015', 6.3, 87080],
#  ['West Side Story', '1961', 7.6, 87052],
#  ['Hereafter', '2010', 6.5, 87047],
#  ['The Conversation', '1974', 7.9, 86963],
#  ['The Experiment', '2001', 7.7, 86813],
#  ["Boys Don't Cry", '1999', 7.6, 86688],
#  ['The American', '2010', 6.3, 86598],
#  ['The International', '2009', 6.5, 86580],
#  ['Hunt for the Wilderpeople', '2016', 7.9, 86364],
#  ['Persona', '1966', 8.1, 86135],
#  ['The Hurricane', '1999', 7.6, 86086],
#  ['The Edge of Seventeen', '2016', 7.4, 85965],
#  ['Ip Man 2', '2010', 7.6, 85925],
#  ['Letters to Juliet', '2010', 6.6, 85708],
#  ['Money Monster', '2016', 6.5, 85649],
#  ['Fences', '2016', 7.2, 85535],
#  ['The Best Exotic Marigold Hotel', '2011', 7.3, 85413],
#  ['Another Earth', '2011', 7.0, 85411],
#  ['The X Files: I Want to Believe', '2008', 6.0, 85343],
#  ['Runaway Jury', '2003', 7.1, 85264],
#  ['The Painted Veil', '2006', 7.5, 85255],
#  ['The Rite', '2011', 6.0, 85203],
#  ['A Nightmare on Elm Street', '2010', 5.2, 85121],
#  ['The Santa Clause', '1994', 6.4, 84897],
#  ['The Girl Who Played with Fire', '2009', 7.2, 84896],
#  ['Notorious', '1946', 8.0, 84668],
#  ['In the Line of Fire', '1993', 7.2, 84623],
#  ["My Sister's Keeper", '2009', 7.4, 84594],
#  ['The Last Emperor', '1987', 7.8, 84551],
#  ['The Box', '2009', 5.6, 84541],
#  ['Fast Times at Ridgemont High', '1982', 7.2, 84538],
#  ['Amour', '2012', 7.9, 84499],
#  ['Edge of Darkness', '2010', 6.6, 84427],
#  ['Dreamcatcher', '2003', 5.5, 84386],
#  ['Phantom Thread', '2017', 7.5, 84352],
#  ['Silence', '2016', 7.2, 84186],
#  ["Nick and Norah's Infinite Playlist", '2008', 6.7, 84153],
#  ['The Host', '2006', 7.0, 83995],
#  ['Monsters', '2010', 6.4, 83971],
#  ['Mean Streets', '1973', 7.3, 83744],
#  ['Revolver', '2005', 6.5, 83692],
#  ['Wild Strawberries', '1957', 8.2, 83531],
#  ['Beginners', '2010', 7.2, 83493],
#  ['What Happened to Monday', '2017', 6.9, 83405],
#  ['The Ballad of Buster Scruggs', '2018', 7.3, 82929],
#  ['The Guardian', '2006', 6.9, 82846],
#  ['Funny Games', '2007', 6.5, 82834],
#  ['Election', '1999', 7.3, 82757],
#  ['Take Shelter', '2011', 7.4, 82704],
#  ['Inherent Vice', '2014', 6.7, 82604],
#  ['Lolita', '1962', 7.6, 82170],
#  ['A Good Year', '2006', 7.0, 82116],
#  ['The Cloverfield Paradox', '2018', 5.6, 81717],
#  ['Persepolis', '2007', 8.1, 81586],
#  ['3 Days to Kill', '2014', 6.2, 81243],
#  ['Clear and Present Danger', '1994', 6.9, 81148],
#  ['The Spiderwick Chronicles', '2008', 6.6, 80994],
#  ['Gifted', '2017', 7.6, 80849],
#  ['Fifty Shades Darker', '2017', 4.6, 80636],
#  ['Harry Brown', '2009', 7.2, 80548],
#  ['Our Idiot Brother', '2011', 6.4, 80524],
#  ['Righteous Kill', '2008', 6.0, 80357],
#  ['The Grapes of Wrath', '1940', 8.1, 80341],
#  ['All About My Mother', '1999', 7.9, 80278],
#  ['Half Nelson', '2006', 7.2, 80241],
#  ['Only Lovers Left Alive', '2013', 7.3, 80179],
#  ['Elephant', '2003', 7.2, 80092],
#  ["It's Complicated", '2009', 6.6, 80087],
#  ['Biutiful', '2010', 7.5, 79992],
#  ['Unthinkable', '2010', 7.1, 79917],
#  ['The Pacifier', '2005', 5.6, 79886],
#  ['Sweet November', '2001', 6.7, 79748],
#  ['We Own the Night', '2007', 6.9, 79604],
#  ['Goon', '2011', 6.8, 79536],
#  ['Out of Sight', '1998', 7.0, 79461],
#  ['Malèna', '2000', 7.5, 79454],
#  ['Beautiful Creatures', '2013', 6.2, 79441],
#  ['Submarine', '2010', 7.3, 79426],
#  ['Three Colors: Red', '1994', 8.1, 79299],
#  ['My Fair Lady', '1964', 7.9, 79263],
#  ['Blood Simple', '1984', 7.6, 79240],
#  ['Cashback', '2006', 7.2, 79182],
#  ['Ghost Dog: The Way of the Samurai', '1999', 7.5, 79138],
#  ['Crazy Heart', '2009', 7.3, 79136],
#  ['Mirror Mirror', '2012', 5.6, 79131],
#  ['Love, Simon', '2018', 7.6, 79115],
#  ['August: Osage County', '2013', 7.2, 79047],
#  ['My Week with Marilyn', '2011', 7.0, 79045],
#  ['Cop Land', '1997', 6.9, 79004],
#  ['Bad Times at the El Royale', '2018', 7.1, 78936],
#  ['A Simple Favor', '2018', 6.9, 78839],
#  ['Finding Forrester', '2000', 7.3, 78790],
#  ['Stuck in Love', '2012', 7.2, 78559],
#  ['Haywire', '2011', 5.8, 78488],
#  ["Monster's Ball", '2001', 7.1, 78418],
#  ['Mississippi Burning', '1988', 7.8, 78366],
#  ['Maid in Manhattan', '2002', 5.2, 78364],
#  ['The New World', '2005', 6.7, 78338],
#  ['Witness', '1985', 7.4, 77976],
#  ['Collateral Beauty', '2016', 6.8, 77835],
#  ['Hide and Seek', '2005', 5.9, 77715],
#  ['Snitch', '2013', 6.5, 77648],
#  ['Three Colors: Blue', '1993', 8.0, 77464],
#  ['The Bling Ring', '2013', 5.6, 77442],
#  ['Beasts of the Southern Wild', '2012', 7.3, 77191],
#  ['Selma', '2014', 7.5, 77144],
#  ['Never Been Kissed', '1999', 6.0, 77129],
#  ['Scrooged', '1988', 7.0, 77117],
#  ['42', '2013', 7.5, 77109],
#  ['La Vie en Rose', '2007', 7.6, 76995],
#  ['Eat Pray Love', '2010', 5.8, 76987],
#  ['Demolition', '2015', 7.0, 76981],
#  ['Secretary', '2002', 7.0, 76922],
#  ['Concussion', '2015', 7.1, 76919],
#  ['Big Eyes', '2014', 7.0, 76771],
#  ['The Handmaiden', '2016', 8.1, 76756],
#  ['Arlington Road', '1999', 7.2, 76457],
#  ['The Fox and the Hound', '1981', 7.3, 76325],
#  ['Dope', '2015', 7.2, 76196],
#  ['Step Up 2: The Streets', '2008', 6.3, 75777],
#  ['Thirteen', '2003', 6.8, 75577],
#  ['Rebel Without a Cause', '1955', 7.8, 75545],
#  ['Patriots Day', '2016', 7.4, 75190],
#  ['Solaris', '2002', 6.2, 75060],
#  ['October Sky', '1999', 7.8, 74779],
#  ['Elite Squad: The Enemy Within', '2010', 8.1, 74773],
#  ['The Night of the Hunter', '1955', 8.0, 74749],
#  ['The Weather Man', '2005', 6.6, 74536],
#  ['Flipped', '2010', 7.7, 74437],
#  ['Jane Eyre', '2011', 7.4, 74365],
#  ['Eddie the Eagle', '2015', 7.4, 74271],
#  ['Wag the Dog', '1997', 7.1, 74242],
#  ['The Last Song', '2010', 5.9, 74196],
#  ['American Graffiti', '1973', 7.5, 74186],
#  ['Frida', '2002', 7.4, 74172],
#  ['The Kite Runner', '2007', 7.6, 74145],
#  ['The Straight Story', '1999', 8.0, 74123],
#  ['Swades', '2004', 8.3, 74013],
#  ['World Trade Center', '2006', 6.0, 73876],
#  ['Sing Street', '2016', 8.0, 73868],
#  ['How to Be Single', '2016', 6.1, 73751],
#  ['Paris, Texas', '1984', 8.1, 73725],
#  ['Centurion', '2010', 6.4, 73720],
#  ['Young Adult', '2011', 6.3, 73645],
#  ['Downsizing', '2017', 5.7, 73558],
#  ['Spanglish', '2004', 6.4, 73552],
#  ['Cocktail', '1988', 5.9, 73218],
#  ['Unfaithful', '2002', 6.7, 73178],
#  ['Risky Business', '1983', 6.8, 73156],
#  ['The Celebration', '1998', 8.1, 73123],
#  ['Gosford Park', '2001', 7.3, 73051],
#  ['A Perfect Murder', '1998', 6.5, 73047],
#  ['The Killing', '1956', 8.0, 73016],
#  ['The Kings of Summer', '2013', 7.2, 72899],
#  ['The Land Before Time', '1988', 7.4, 72875],
#  ['The Piano', '1993', 7.6, 72733],
#  ['The Searchers', '1956', 8.0, 72680],
#  ['The Sea Inside', '2004', 8.0, 72595],
#  ['The Hudsucker Proxy', '1994', 7.3, 72463],
#  ['Beastly', '2011', 5.6, 72285],
#  ['The Duchess', '2008', 6.9, 72239],
#  ['Felon', '2008', 7.5, 71980],
#  ['Eye in the Sky', '2015', 7.3, 71928],
#  ['The Day the Earth Stood Still', '1951', 7.8, 71882],
#  ['Mona Lisa Smile', '2003', 6.5, 71774],
#  ['The Circle', '2017', 5.3, 71484],
#  ['Synecdoche, New York', '2008', 7.5, 71483],
#  ...]

# %%
for k,v in tmp.items():
    print(k, random.sample(v[:100],1))
# Out:
# Romance [['The Great Gatsby', '2013', 7.3, 429190]]
# Drama [['A Beautiful Mind', '2001', 8.2, 764491]]
# Adventure [['Harry Potter and the Goblet of Fire', '2005', 7.7, 484768]]
# Fantasy [['Prince of Persia: The Sands of Time', '2010', 6.6, 253221]]
# Biography [['Lion', '2016', 8.1, 179422]]
# History [['The Post', '2017', 7.2, 105892]]
# War [['MASH', '1970', 7.6, 63017]]
# Comedy [['Tropic Thunder', '2008', 7.0, 349631]]
# Crime [['To Kill a Mockingbird', '1962', 8.3, 269256]]
# Mystery [['Saw II', '2005', 6.6, 216531]]
# Horror [['I Am Legend', '2007', 7.2, 629854]]
# Thriller [['The Dark Knight Rises', '2012', 8.4, 1374318]]
# Western [['Renegade', '2004', 5.2, 9921]]
# Music [['The Broken Circle Breakdown', '2012', 7.8, 36233]]
# Action [['Star Wars: The Last Jedi', '2017', 7.2, 454844]]
# Family [['The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', '2005', 6.9, 337906]]
# Sci-Fi [['Terminator Salvation', '2009', 6.6, 318725]]
# Sport [['Trouble with the Curve', '2012', 6.8, 55823]]
# Documentary [['Icarus', '2017', 7.9, 28273]]
# Musical [['Monkey Business', '1931', 7.6, 10380]]
# Film-Noir [['The Desperate Hours', '1955', 7.5, 7963]]
# Animation [['Sausage Party', '2016', 6.2, 157586]]
# News [['Bonsai People: The Vision of Muhammad Yunus', '2011', 8.9, 41]]
# Adult [["The Farmer's Daughters", '1976', 4.9, 148]]
# Talk-Show [['Revenge of the Motorcycle Mama', '1972', 6.8, 6]]
# Short [['Nobody Knows', '2009', 7.4, 12]]
# Reality-TV [['Markiplier Being Dumb on Stage in Front of 1000 People with Friends at PAX East', '2015', 7.6, 13]]
# Game-Show [["Wait Wait Don't Tell Me Live!", '2013', 9.0, 7]]
