# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import random
import json

# %%
imdb_df = pd.read_csv('IMDB_Final_Movies.csv')
imdb_df.head()
# Out:
#       tconst                    primaryTitle                   originalTitle  \
# 0  tt0000009                      Miss Jerry                      Miss Jerry
# 1  tt0000630                          Hamlet                          Amleto
# 2  tt0000679  The Fairylogue and Radio-Plays  The Fairylogue and Radio-Plays
# 3  tt0000886       Hamlet, Prince of Denmark                          Hamlet
# 4  tt0001482           As in a Looking Glass           As in a Looking Glass
#
#                 titles from US/UK  startYear region             genres  \
# 0                      Miss Jerry     1894.0     US            Romance
# 1                          Hamlet     1908.0     US              Drama
# 2  The Fairylogue and Radio-Plays     1908.0     US  Adventure,Fantasy
# 3       Hamlet, Prince of Denmark     1910.0     US              Drama
# 4           As in a Looking Glass     1911.0     US              Drama
#
#              directors_names              writers_names  \
# 0            Alexander Black            Alexander Black
# 1             Mario Caserini        William Shakespeare
# 2  Francis Boggs/Otis Turner  L. Frank Baum/Otis Turner
# 3           Gérard Bourgeois        William Shakespeare
# 4              D.W. Griffith            George Hennessy
#
#                                            cast_name  averageRating  numVotes
# 0                  Blanche Bayliss/William Courtenay            5.5        78
# 1                              Fernanda Negri Pouget            2.9        11
# 2  Evelyn Judson/Sam 'Smiling' Jones/Annabel Jeph...            4.8        33
# 3                                  Jean Mounet-Sully            5.1        19
# 4  Wilfred Lucas/George Hennessy/Claire McDowell/...            5.1        26

# %%
print(imdb_df.shape)
imdb_df.dropna(inplace=True)
print(imdb_df.shape)
# Out:
# (79219, 12)
# (79211, 12)

# %%
imdb_df.to_csv("IMDB_Final_Movies.csv", index=False)

# %%
genre_to_movie_rating_pair = defaultdict(list)
for i in range(imdb_df.shape[0]):
    title = imdb_df.iloc[i]['primaryTitle']
    year = str(int(imdb_df.iloc[i]['startYear']))
    genres = imdb_df.iloc[i]['genres'].split(',')
    rate = float(imdb_df.iloc[i]['averageRating'])
    for g in genres:
        genre_to_movie_rating_pair[g].append((title,year,rate))

# %%
sorted_genre_to_movie_rating_pair = defaultdict(list)
for k,v in genre_to_movie_rating_pair.items():
    sorted_genre_to_movie_rating_pair[k] = sorted(v, key=lambda x: x[2], reverse=True)

# %%
json.dump(sorted_genre_to_movie_rating_pair, open("sorted_movies_for_genres.json",'w'))

# %%
tmp = json.load(open("sorted_movies_for_genres.json"))
tmp['Drama']
# Out:
# [['Play the Flute', '2019', 9.8],
#  ['Two Girls', '2018', 9.8],
#  ['SoulHood', '2017', 9.8],
#  ['To Be Alone', '2017', 9.7],
#  ['Turnover', '2019', 9.6],
#  ['The Narcissists', '2017', 9.6],
#  ['The God of Small Things', '2017', 9.6],
#  ['Thrasher Road', '2018', 9.6],
#  ['Blue', '2018', 9.5],
#  ['The Broken Rose', '2018', 9.5],
#  ['Palace', '2018', 9.5],
#  ['Hamlet in the Golden Vale', '2018', 9.5],
#  ['Peranbu', '2018', 9.5],
#  ['Turnipseed', '2008', 9.4],
#  ['The Soul Agency', '2009', 9.4],
#  ['Into the Night', '2011', 9.4],
#  ['Albanian Gangster', '2018', 9.4],
#  ['Overwhelm the Sky', '2018', 9.4],
#  ['What Matters', '2018', 9.4],
#  ['Tortured for Christ', '2018', 9.4],
#  ['Death of Love', '2017', 9.4],
#  ['The Shawshank Redemption', '1994', 9.3],
#  ['Old Coaches', '2002', 9.3],
#  ['The Sinking Ship', '2003', 9.3],
#  ['Perhaps, Somewhere', '2009', 9.3],
#  ['Substance', '2011', 9.3],
#  ['Threading Needles', '2011', 9.3],
#  ['Redemption Boys', '2012', 9.3],
#  ['Basically Frightened: The Musical Madness of Colonel Bruce Hampton',
#   '2012',
#   9.3],
#  ['Wheels', '2014', 9.3],
#  ['Our Beautiful Secret', '2013', 9.3],
#  ['Carroll Park', '2013', 9.3],
#  ['6B: An Anthology of Hawaii Films', '2011', 9.3],
#  ['Another Chance', '2013', 9.3],
#  ['Donovan', '2017', 9.3],
#  ['I Will Dance', '2015', 9.3],
#  ['Antique Prayers', '2014', 9.3],
#  ['The Ataxian', '2015', 9.3],
#  ['The Food Cure: Hope or Hype?', '2018', 9.3],
#  ['One Penny', '2017', 9.3],
#  ["Sienna's Choice", '2016', 9.3],
#  ['Hold On', '2017', 9.3],
#  ['Senioritis', '2018', 9.3],
#  ['Just Say Goodbye', '2017', 9.3],
#  ['Sustained', '2017', 9.3],
#  ['The Godfather', '1972', 9.2],
#  ['Callback', '2005', 9.2],
#  ['Banana Moon', '2003', 9.2],
#  ['View in Black & White', '2005', 9.2],
#  ['What I Want', '2004', 9.2],
#  ['The Situation', '2006', 9.2],
#  ['From the Midst of Pain', '2010', 9.2],
#  ['The Matter with Clark', '2008', 9.2],
#  ['GRRF: The Sound of Suicide Postponement', '2009', 9.2],
#  ['Hurry Home', '2010', 9.2],
#  ['The Corners', '2010', 9.2],
#  ['Bare Knuckle', '2014', 9.2],
#  ["Payin' the Price", '2011', 9.2],
#  ['For Serious', '2014', 9.2],
#  ['Townbiz', '2010', 9.2],
#  ['Walk On', '2013', 9.2],
#  ['Write Now', '2012', 9.2],
#  ['Papou', '2014', 9.2],
#  ["Travis: A Soldier's Story", '2013', 9.2],
#  ['Thou Shalt Not Kill', '2014', 9.2],
#  ['Worst Kind of People', '2013', 9.2],
#  ['A Dog Named Gucci', '2015', 9.2],
#  ["Loser's Crown", '2014', 9.2],
#  ['The Sand Box', '2016', 9.2],
#  ['Lights Camera Bullshit', '2014', 9.2],
#  ['Adventures of Miss Fit', '2016', 9.2],
#  ['When the Boys Walk In', '2014', 9.2],
#  ['Forgive Me Father', '2015', 9.2],
#  ['Andrea Doria: Are the Passengers Saved?', '2016', 9.2],
#  ['Miles Between Us', '2017', 9.2],
#  ['The Dunning Man', '2017', 9.2],
#  ['Back to One: First Position', '2017', 9.2],
#  ["Poor Mama's Boy", '2016', 9.2],
#  ['Upstate Story', '2018', 9.2],
#  ['Mail Time', '2016', 9.2],
#  ['Horseshoe Finale', '2015', 9.2],
#  ['Delaware Shore', '2018', 9.2],
#  ['Off the Rails', '2018', 9.2],
#  ['Silicon Beach', '2018', 9.2],
#  ['Amanda McKay', '2018', 9.2],
#  ['Parallel Chords', '2018', 9.2],
#  ['People Like Me', '2017', 9.2],
#  ['Godspell', '2017', 9.2],
#  ['Deceptive Heart', '2018', 9.2],
#  ['The Last Guest', '2017', 9.2],
#  ['Party Talk', '2015', 9.2],
#  ['La rubia Mireya', '1948', 9.1],
#  ['Clouds at Sunset', '1967', 9.1],
#  ['Igorota', '1968', 9.1],
#  ['The Cloud of Unknowing', '2002', 9.1],
#  ['From Wharf Rats to Lords of the Docks', '2007', 9.1],
#  ['Moonbeams', '2001', 9.1],
#  ['Of Earth and Sky', '1996', 9.1],
#  ['Love Equation', '2010', 9.1],
#  ['Kisses, Chloe', '2010', 9.1],
#  ['Amity', '2012', 9.1],
#  ['County Fair, Texas', '2015', 9.1],
#  ['Heart KPop', '2013', 9.1],
#  ["A Father's Journey", '2015', 9.1],
#  ['Cold Empty Hearts', '2014', 9.1],
#  ['Pinch', '2016', 9.1],
#  ['Evidence of Harm', '2015', 9.1],
#  ['Touched by an Angel', '2015', 9.1],
#  ['The Chain', '2014', 9.1],
#  ['Loud Places', '2017', 9.1],
#  ['In the Orchard', '2018', 9.1],
#  ['Meme', '2018', 9.1],
#  ['A Second Chance', '2018', 9.1],
#  ['Psychic Murder', '2017', 9.1],
#  ['Major Arcana', '2018', 9.1],
#  ['The Idea of Manhood', '2018', 9.1],
#  ['Pain and Music', '2016', 9.1],
#  ['Chasing Bullitt', '2018', 9.1],
#  ['On Dangerous Ground', '1917', 9.0],
#  ['The Godfather: Part II', '1974', 9.0],
#  ['Adverse Possession', '1998', 9.0],
#  ['Trumpet #7', '1991', 9.0],
#  ['Making Metamorphosis', '2001', 9.0],
#  ['Holding On', '1992', 9.0],
#  ['The Last American', '2003', 9.0],
#  ['Mere Acquaintance', '2003', 9.0],
#  ['Louie the Moon', '2004', 9.0],
#  ['The Highlife', '2003', 9.0],
#  ['The Dark Knight', '2008', 9.0],
#  ['For Love & Stacie', '2006', 9.0],
#  ['Singularity', '2007', 9.0],
#  ['We Pedal Uphill', '2008', 9.0],
#  ['Fear of Attraction', '2009', 9.0],
#  ['Not Fade Away', '2008', 9.0],
#  ['Truth', '2007', 9.0],
#  ['Wild Ride', '2010', 9.0],
#  ['The Wolf at the Door', '2008', 9.0],
#  ['Yeardley', '2010', 9.0],
#  ['When Strangers Meet', '2013', 9.0],
#  ['The Distance Between the Apple and the Tree', '2009', 9.0],
#  ['Toobie', '2007', 9.0],
#  ['Shattered Focus', '2009', 9.0],
#  ['The Meaning of Filo', '2009', 9.0],
#  ['Ashes', '2009', 9.0],
#  ['Step Away from the Stone', '2010', 9.0],
#  ['Frankenstein', '2011', 9.0],
#  ['Through a Lens Darkly: Grief, Loss and C.S. Lewis', '2011', 9.0],
#  ['Boy with Blue', '2011', 9.0],
#  ['Carl', '2011', 9.0],
#  ['Placebo', '2012', 9.0],
#  ['Pui Chan: Kung Fu Pioneer', '2012', 9.0],
#  ['Making Light In Terezin', '2012', 9.0],
#  ['The Sandman', '2011', 9.0],
#  ['The Volunteer', '2013', 9.0],
#  ['The Summer Before', '2012', 9.0],
#  ['A Quick Buck', '2012', 9.0],
#  ['Company M: A Mob of Soldiers', '2012', 9.0],
#  ['L.A. Superheroes', '2013', 9.0],
#  ['Last Curtain Call', '2014', 9.0],
#  ['The 12 Lives of Sissy Carlyle', '2017', 9.0],
#  ['The Last Night Inn', '2016', 9.0],
#  ['North Passage', '2014', 9.0],
#  ['The Breach', '2014', 9.0],
#  ["Nathan's Kingdom", '2018', 9.0],
#  ['APOM', '2014', 9.0],
#  ['One: A Story of Love and Equality', '2014', 9.0],
#  ['JackRabbit 29', '2017', 9.0],
#  ['Lone Rivers', '2013', 9.0],
#  ['The Last Gift', '2014', 9.0],
#  ['The Reading of Hammer Ridge', '2014', 9.0],
#  ['Two-Eleven', '2015', 9.0],
#  ['Until 20', '2015', 9.0],
#  ['Ironwood', '2017', 9.0],
#  ['For the Love of Ruth', '2015', 9.0],
#  ['My Sunset Girl', '2016', 9.0],
#  ['Lost Signals', '2016', 9.0],
#  ['Go Crazy Go Mad', '2018', 9.0],
#  ['The Meanest Man in Texas', '2017', 9.0],
#  ['M. Pearls, A.A.L. The Movie', '2017', 9.0],
#  ['1040 Not So EZ', '2017', 9.0],
#  ['In for Life', '2015', 9.0],
#  ['Our Stories', '2014', 9.0],
#  ['Found', '2016', 9.0],
#  ['Catfish Fillets', '2016', 9.0],
#  ['The Filmmaker', '2018', 9.0],
#  ['Come As You Are', '2019', 9.0],
#  ['Paper City Burnout', '2018', 9.0],
#  ['Super Deluxe', '2019', 9.0],
#  ['Kid Brother', '2017', 9.0],
#  ['The Question', '2017', 9.0],
#  ['The Irish Goodbye', '2017', 9.0],
#  ['Sinners Wanted', '2018', 9.0],
#  ['The Restless Sex', '1920', 8.9],
#  ['12 Angry Men', '1957', 8.9],
#  ["Who's Singin' Over There?", '1980', 8.9],
#  ["Schindler's List", '1993', 8.9],
#  ['Pulp Fiction', '1994', 8.9],
#  ['The Lord of the Rings: The Return of the King', '2003', 8.9],
#  ['Dmitry II', '1982', 8.9],
#  ['Promise Me This', '2005', 8.9],
#  ['Oh, Mr. Faulkner, Do You Write?', '2006', 8.9],
#  ['Caravaggio and My Mother the Pope', '2018', 8.9],
#  ['The Rise and Fall of Miss Thang', '2007', 8.9],
#  ['Crescent City', '2011', 8.9],
#  ['Mozlym', '2008', 8.9],
#  ['East L.A.', '2008', 8.9],
#  ['The Rebel Heart', '2009', 8.9],
#  ['Losing You', '2009', 8.9],
#  ['Truly Blessed', '2009', 8.9],
#  ['Dixie Times', '2012', 8.9],
#  ['Schism', '2008', 8.9],
#  ['The Likes of Us', '2009', 8.9],
#  ['Bonsai People: The Vision of Muhammad Yunus', '2011', 8.9],
#  ['The Beekeepers', '2010', 8.9],
#  ['Afghan Hound', '2010', 8.9],
#  ['40 Point Plan', '2012', 8.9],
#  ['Nothing Against Life', '2013', 8.9],
#  ['American Cliche', '2013', 8.9],
#  ['Dark Blue', '2011', 8.9],
#  ['In a Cage', '2013', 8.9],
#  ['Betterthandead', '2012', 8.9],
#  ['The Space Jockey Pursuit', '2013', 8.9],
#  ['Explode for Me', '2012', 8.9],
#  ['Fading Away', '2013', 8.9],
#  ["A Lotus 'Til Reckoning", '2017', 8.9],
#  ['The Widowers', '2014', 8.9],
#  ['At the Maple Grove', '2014', 8.9],
#  ['The Last Alleycat', '2016', 8.9],
#  ['Black Ruby', '2017', 8.9],
#  ['Hot Air', '2016', 8.9],
#  ['A Timeless Love', '2016', 8.9],
#  ['My Week in Atheism', '2014', 8.9],
#  ['Spin the Plate', '2017', 8.9],
#  ['The Jones Family Will Make a Way', '2015', 8.9],
#  ['Quality Problems', '2017', 8.9],
#  ['Por Sofia', '2016', 8.9],
#  ['The Hunger', '1984', 8.9],
#  ['Not Alone', '2019', 8.9],
#  ['Return of the Thumb', '2018', 8.9],
#  ['Groupers', '2019', 8.9],
#  ['Chi Nu Legacy', '2017', 8.9],
#  ['To Be a Soldier', '2018', 8.9],
#  ['Small Group', '2018', 8.9],
#  ['Emergency Landing', '2016', 8.9],
#  ['Watch What You Pray For', '2016', 8.9],
#  ['Shotgun Honey', '2017', 8.9],
#  ['Off the Record', '2019', 8.9],
#  ['Walk on Water', '2017', 8.9],
#  ['Princess of the Row', '2019', 8.9],
#  ['The Stuff', '2018', 8.9],
#  ['Gwendolyn', '2017', 8.9],
#  ['Saviors', '2018', 8.9],
#  ['Caeli Auxilium', '2015', 8.9],
#  ['818', '2018', 8.9],
#  ['Cecilia of the Pink Roses', '1918', 8.8],
#  ['His Glorious Night', '1929', 8.8],
#  ['A Love Story', '1954', 8.8],
#  ["The Human Condition III: A Soldier's Prayer", '1961', 8.8],
#  ['Sofi', '1968', 8.8],
#  ['Forrest Gump', '1994', 8.8],
#  ['The Lord of the Rings: The Fellowship of the Ring', '2001', 8.8],
#  ['The Pyramid', '1975', 8.8],
#  ['Fight Club', '1999', 8.8],
#  ['Chimera House', '1999', 8.8],
#  ['The Poison Tasters', '1995', 8.8],
#  ['Love Commands', '1939', 8.8],
#  ['The Final Journey', '2010', 8.8],
#  ['Salt Without Soup', '1990', 8.8],
#  ['Until Morning', '2002', 8.8],
#  ['The Heart of the Mother', '1993', 8.8],
#  ['Mainly Etc.', '2001', 8.8],
#  ['Rising Shores', '2007', 8.8],
#  ['Reception to Follow', '1995', 8.8],
#  ['A Boy a Girl and a Dead Cat', '1999', 8.8],
#  ["God's Forgotten House", '2005', 8.8],
#  ['Tears of a Clown', '2005', 8.8],
#  ['Indocumentados', '2004', 8.8],
#  ['American Skin 2: Eagles Gathering', '2005', 8.8],
#  ['Mercy Street', '2006', 8.8],
#  ['September 12th', '2005', 8.8],
#  ['Exodus 20:13', '2007', 8.8],
#  ['Welcome to Tolono', '2007', 8.8],
#  ['The Summoning of Everyman', '2007', 8.8],
#  ['A.k.a. Nikki S. Lee', '2006', 8.8],
#  ['Cuando volveras', '2008', 8.8],
#  ['Alexander Jamieson', '2017', 8.8],
#  ['Under One Sun', '2009', 8.8],
#  ['One California Day', '2007', 8.8],
#  ['Chicago Heights', '2009', 8.8],
#  ['The Parts Left Over', '2009', 8.8],
#  ['The Basket Case', '2006', 8.8],
#  ['The Aspern Papers', '2010', 8.8],
#  ['Hollow Spaces', '2009', 8.8],
#  ['Coffka', '2009', 8.8],
#  ['The Dream Play', '2011', 8.8],
#  ['Shades of Gray', '2014', 8.8],
#  ['I Breathe', '2010', 8.8],
#  ['Les Misérables in Concert: The 25th Anniversary', '2010', 8.8],
#  ["Destiny's Calling", '2011', 8.8],
#  ['Young Birds Fly', '2011', 8.8],
#  ['The Vanilla Series: The Cougar Trap', '2009', 8.8],
#  ['The Clear', '2011', 8.8],
#  ['Tangled Up in Blue', '2011', 8.8],
#  ['Hayseeds and Scalawags', '2011', 8.8],
#  ['The Phantom of the Opera at the Royal Albert Hall', '2011', 8.8],
#  ['Francis of Brooklyn', '2012', 8.8],
#  ['The Racket Boys', '2011', 8.8],
#  ['Living Lost', '2016', 8.8],
#  ['Rabbit Stories', '2013', 8.8],
#  ['A Woman Called Job', '2014', 8.8],
#  ['The Nextnik', '2013', 8.8],
#  ['Homecoming', '2012', 8.8],
#  ["Writer's Block", '2012', 8.8],
#  ['Pester', '2014', 8.8],
#  ['The Street Where We Live', '2017', 8.8],
#  ['Hall of Fame', '2012', 8.8],
#  ['The Way of Glass', '2012', 8.8],
#  ['Sophisticated Acquaintance', '2007', 8.8],
#  ['Americano', '2013', 8.8],
#  ['On the Art of War', '2012', 8.8],
#  ['Furious Beauty', '2013', 8.8],
#  ['Virginia Running', '2012', 8.8],
#  ['If You Really Knew Me', '2013', 8.8],
#  ['Fear and Love', '2017', 8.8],
#  ['The Hunting', '2011', 8.8],
#  ['Let Them Have Their Way', '2014', 8.8],
#  ['Red Right Return', '2015', 8.8],
#  ['Coast Mafia', '2014', 8.8],
#  ['Bach en Madrid', '2013', 8.8],
#  ["Lola's Last Letter", '2016', 8.8],
#  ['Borderlands', '2013', 8.8],
#  ['Victims of Fun', '2014', 8.8],
#  ['The Life and Death of Julian Finn', '2016', 8.8],
#  ['Psychopath', '2014', 8.8],
#  ['Seven Lovers', '2014', 8.8],
#  ['Stuck', '2015', 8.8],
#  ['Inside Room 234', '2014', 8.8],
#  ['Snow Day', '2014', 8.8],
#  ['The Trigger', '2018', 8.8],
#  ['Our Apartment', '2015', 8.8],
#  ['Beatbox', '2015', 8.8],
#  ['Nine Seconds', '2017', 8.8],
#  ['Interior Night', '2016', 8.8],
#  ["My Mother's Replacement", '2015', 8.8],
#  ['Rental', '2017', 8.8],
#  ['Darkness Has Covered My Light', '2018', 8.8],
#  ['Nothing Serious', '2015', 8.8],
#  ["Baytown's Finest", '2016', 8.8],
#  ['You & Me', '2018', 8.8],
#  ['2wenty9ine', '2006', 8.8],
#  ['Hurt', '2016', 8.8],
#  ['One Last Prayer', '2017', 8.8],
#  ['Peaks and Valleys', '2019', 8.8],
#  ['Free Ride', '2017', 8.8],
#  ['Fishbowl', '2018', 8.8],
#  ['The Lines', '2017', 8.8],
#  ['The Lies We Tell But the Secrets We Keep Part 1', '2011', 8.8],
#  ['The Executive Empress', '2017', 8.8],
#  ['Cute With Bad Qualities', '2017', 8.8],
#  ['96', '2018', 8.8],
#  ['If I Could Run', '2018', 8.8],
#  ['The Exceptionals', '2017', 8.8],
#  ['Heading Home: The Tale of Team Israel', '2018', 8.8],
#  ['Teeth', '2017', 8.8],
#  ['I Wrote This For You', '2018', 8.8],
#  ['Auggie', '2019', 8.8],
#  ['Seven Samurai', '1954', 8.7],
#  ['Harakiri', '1962', 8.7],
#  ["One Flew Over the Cuckoo's Nest", '1975', 8.7],
#  ['Born of Water', '1976', 8.7],
#  ['Your Wife, My Wife', '1988', 8.7],
#  ['The Lord of the Rings: The Two Towers', '2002', 8.7],
#  ['Father of a Soldier', '1965', 8.7],
#  ['The Gifted', '1999', 8.7],
#  ["L'Orfeo", '1978', 8.7],
#  ['Death and Taxis', '2007', 8.7],
#  ['Black & White: A Love Story', '1996', 8.7],
#  ['S detza na more', '1972', 8.7],
#  ['Only in Hollywood', '2002', 8.7],
#  ['Ghosts of Genius', '2003', 8.7],
#  ['American Generator', '2003', 8.7],
#  ['Surviving in L.A.', '2019', 8.7],
#  ['El escape de los Santos', '2005', 8.7],
#  ['Fairfield, Idaho', '2007', 8.7],
#  ['Indiscretion', '2006', 8.7],
#  ['Viola', '2006', 8.7],
#  ['Dust of Life', '2006', 8.7],
#  ['Road to Pecumsecah', '2008', 8.7],
#  ['Chance Encounter', '2008', 8.7],
#  ['Perception', '2009', 8.7],
#  ['This Bitter Earth', '2012', 8.7],
#  ['Against the Grain', '2008', 8.7],
#  ['Darling Nikki: The Movie', '2008', 8.7],
#  ['Grand Slammed', '2010', 8.7],
#  ['The Hypocritic Oath', '2009', 8.7],
#  ["The Shot Felt 'Round the World", '2010', 8.7],
#  ['Losing Ground', '2008', 8.7],
#  ['Dig', '2010', 8.7],
#  ['The Heart of No Place', '2009', 8.7],
#  ['20 Mississippi', '2009', 8.7],
#  ['Something Missie in the Life of Jordan Bank', '2010', 8.7],
#  ['Joel and Julie', '2009', 8.7],
#  ['The Death of Richard Young', '2009', 8.7],
#  ['Devils Inside', '2012', 8.7],
#  ['Peep Game', '2010', 8.7],
#  ["The Friends We Haven't Met Yet", '2009', 8.7],
#  ['Horrible Child', '2008', 8.7],
#  ['Hamlin Pond', '2009', 8.7],
#  ['Semper Fidel', '2014', 8.7],
#  ['Ultimate Reality', '2010', 8.7],
#  ['The Mudman', '2011', 8.7],
#  ['The Forest Is Red', '2012', 8.7],
#  ['Urban Crazy', '2010', 8.7],
#  ['Neon Sky', '2013', 8.7],
#  ['Chasing Home', '2012', 8.7],
#  ['The Stonehouse Lounge', '2011', 8.7],
#  ['When the Time Comes', '2011', 8.7],
#  ['Best in Blue', '2011', 8.7],
#  ['Lost Angels', '2014', 8.7],
#  ['Sharia', '2016', 8.7],
#  ['Less Lost', '2012', 8.7],
#  ['The Miracle of Danny', '2008', 8.7],
#  ['While We Were', '2016', 8.7],
#  ["Mommy, I'm a Bastard!", '2013', 8.7],
#  ['The Other Kind', '2015', 8.7],
#  ['Lights Out', '2013', 8.7],
#  ['Perry & Emile', '2012', 8.7],
#  ['Open Tables', '2015', 8.7],
#  ['The Immigration Lawyer: Shattered Freedom', '2013', 8.7],
#  ['Still Dreaming', '2014', 8.7],
#  ['Justice Denied', '2013', 8.7],
#  ['Ode in Blood', '2013', 8.7],
#  ['Persistence of Memory', '2014', 8.7],
#  ['Guys Reading Poems', '2016', 8.7],
#  ["Victori: The Truth Just Can't Be One Thing", '2015', 8.7],
#  ['Walking Man', '2014', 8.7],
#  ['Only Child', '2015', 8.7],
#  ['Coriolanus', '2014', 8.7],
#  ['Uncommitted', '2015', 8.7],
#  ['Her Little Secret', '2017', 8.7],
#  ['The Polar Bear Club', '2014', 8.7],
#  ['Life Is a Dream', '2014', 8.7],
#  ['5 Seasons: The Movie', '2013', 8.7],
#  ['The Endless Love of Salome', '2018', 8.7],
#  ['Hemalkasa', '2014', 8.7],
#  ['I Call First', '2015', 8.7],
#  ['August in Berlin', '2017', 8.7],
#  ['Khange Tha Game', '2016', 8.7],
#  ['Deficiency Notice', '2016', 8.7],
#  ['Suficiente coraje', '2016', 8.7],
#  ['We Got Lucky', '2016', 8.7],
#  ['From the Kill Pen', '2016', 8.7],
#  ["Where We're Meant to Be", '2016', 8.7],
#  ['Sachin', '2017', 8.7],
#  ["Here's to Wishing I Had My Cats at the Rapture", '2014', 8.7],
#  ['Generic Fate', '2015', 8.7],
#  ['Black Cat', '2017', 8.7],
#  ['The Father and the Bear', '2016', 8.7],
#  ['Funny Man', '2016', 8.7],
#  ['Without You', '2018', 8.7],
#  ['Our Little Secret', '2017', 8.7],
#  ['Camp William', '2015', 8.7],
#  ['Revisions', '2016', 8.7],
#  ['Mazurkas', '2016', 8.7],
#  ['Putas - Ley de Vida -', '2016', 8.7],
#  ['Stadium Anthems', '2018', 8.7],
#  ['Jewtah', '2018', 8.7],
#  ['100 Blocks', '2017', 8.7],
#  ['Structural Amendment', '2016', 8.7],
#  ['Solutions', '2017', 8.7],
#  ['And the Boys Go', '2017', 8.7],
#  ['The Order of Three', '2015', 8.7],
#  ['Rich Kids', '2018', 8.7],
#  ["If You're Gone", '2019', 8.7],
#  ['Uri: The Surgical Strike', '2019', 8.7],
#  ['Yatra', '2019', 8.7],
#  ['Rags', '1915', 8.6],
#  ['The Wolf Man', '1915', 8.6],
#  ['Outside These Walls', '1939', 8.6],
#  ["It's a Wonderful Life", '1946', 8.6],
#  ['The Human Condition I: No Greater Love', '1959', 8.6],
#  ['The Human Condition II: Road to Eternity', '1959', 8.6],
#  ['The Witness', '1969', 8.6],
#  ['The Goat Horn', '1971', 8.6],
#  ['Looking Up', '1977', 8.6],
#  ['Léon: The Professional', '1994', 8.6],
#  ['Life Is Beautiful', '1997', 8.6],
#  ['The Green Mile', '1999', 8.6],
#  ['Saving Private Ryan', '1998', 8.6],
#  ['The North End', '1997', 8.6],
#  ['Staccato Purr of the Exhaust', '1996', 8.6],
#  ['W.I.A. Wounded in Action', '1966', 8.6],
#  ['A Perfect Little Man', '1999', 8.6],
#  ['Landfall', '2001', 8.6],
#  ['City of God', '2002', 8.6],
#  ["My Brother's Light", '2002', 8.6],
#  ['West Bank Brooklyn', '2002', 8.6],
#  ['Anatomy of a Fight', '2003', 8.6],
#  ['The Pearl', '2005', 8.6],
#  ['Olga Benario - Ein Leben für die Revolution', '2004', 8.6],
#  ['One Evening', '2004', 8.6],
#  ['Midnight Money', '2006', 8.6],
#  ['The Grasslands', '2011', 8.6],
#  ['Bloom', '2005', 8.6],
#  ['Interstellar', '2014', 8.6],
#  ['The Catalpa Rescue', '2007', 8.6],
#  ['Cafe Coexistence', '2009', 8.6],
#  ['Home', '2009', 8.6],
#  ["Seducer's Fall", '2007', 8.6],
#  ['B.O.H.I.C.A.', '2008', 8.6],
#  ['Inside a Change', '2009', 8.6],
#  ['Do Not Disturb', '2009', 8.6],
#  ['ER EXperience', '2009', 8.6],
#  ['Bloom', '2011', 8.6],
#  ['Limbo Lounge', '2010', 8.6],
#  ['Lefty', '2009', 8.6],
#  ['Sex and Justice', '2008', 8.6],
#  ['Every Hidden Thing', '2008', 8.6],
#  ["My Father's Daughter", '2002', 8.6],
#  ['Trap House', '2009', 8.6],
#  ['Losing Faith', '2009', 8.6],
#  ["Don't Go to Strangers", '2008', 8.6],
#  ['The Humdrummer', '2013', 8.6],
#  ["Five Days in the 'A'", '2009', 8.6],
#  ['Sex and Imagining', '2009', 8.6],
#  ['In Focus', '2010', 8.6],
#  ['Out of Place', '2009', 8.6],
#  ['1 in 3', '2010', 8.6],
#  ['Pledging Allegiance', '2011', 8.6],
#  ['Honorable Retribution', '2010', 8.6],
#  ['The Art of Women', '2010', 8.6],
#  ['Caos & Consequences', '2011', 8.6],
#  ['Hollywood Whores', '2011', 8.6],
#  ['Out of Focus', '2010', 8.6],
#  ['A Perfect Life', '2011', 8.6],
#  ['Deference', '2011', 8.6],
#  ['The Green Bandits', '2013', 8.6],
#  ['Lars the Emo Kid', '2015', 8.6],
#  ['Erase una vez en Bolivia', '2011', 8.6],
#  ['Finding Her Way Home', '2011', 8.6],
#  ['Compromise', '2011', 8.6],
#  ['Taken in', '2011', 8.6],
#  ['As I Die Slowly', '2011', 8.6],
#  ['Sexually Frank', '2012', 8.6],
#  ['After the Triumph of Your Birth', '2012', 8.6],
#  ['Hero of the Day', '2012', 8.6],
#  ['Lost in Reality', '2012', 8.6],
#  ['The Emigrant', '2012', 8.6],
#  ['Kin', '2012', 8.6],
#  ['Morality', '2016', 8.6],
#  ['Tragedy of a Mother and Son', '2012', 8.6],
#  ['High & Outside: a baseball noir', '2017', 8.6],
#  ['The Pony Man', '2012', 8.6],
#  ['Misled', '2015', 8.6],
#  ['The Slut Always Rides Shotgun', '2013', 8.6],
#  ['Ipseity', '2013', 8.6],
#  ['Shift of the Ages', '2012', 8.6],
#  ['I Hate You', '2017', 8.6],
#  ['Love My Country', '2015', 8.6],
#  ['120 Days', '2013', 8.6],
#  ['Hope for Hurting Hearts', '2013', 8.6],
#  ['Higher Education', '2013', 8.6],
#  ['By Jingo', '2015', 8.6],
#  ['Bound: Africans versus African Americans', '2014', 8.6],
#  ['Falling Backwards', '2013', 8.6],
#  ['Melfi', '2013', 8.6],
#  ['Suburbanite', '2014', 8.6],
#  ['Adios Vaya Con Dios', '2014', 8.6],
#  ['Tarot: A Documentary Love Story', '2014', 8.6],
#  ['Triggered', '2012', 8.6],
#  ['Mine 9', '2019', 8.6],
#  ['Vegas Vikings', '2014', 8.6],
#  ['A Public Ransom', '2014', 8.6],
#  ['Road Rage', '2016', 8.6],
#  ['The Redemption of Benjamin Black', '2014', 8.6],
#  ['Terrible Love', '2014', 8.6],
#  ['Crave: a True Story', '2013', 8.6],
#  ['Simply gay le film', '2014', 8.6],
#  ['Seven Hours in Heaven', '2015', 8.6],
#  ['Kid Cohen', '2014', 8.6],
#  ['We Only Know So Much', '2018', 8.6],
#  ['Sertão: Veredas', '2008', 8.6],
#  ['Found on South Street', '2015', 8.6],
#  ['Hamlet', '2015', 8.6],
#  ['Good Friday', '2014', 8.6],
#  ['ASCENSION... I Am Not My Mother', '2015', 8.6],
#  ['Here We Are', '2017', 8.6],
#  ['The Texture of Falling', '2018', 8.6],
#  ['Joy Comes in the Morning', '2017', 8.6],
#  ['Pope', '2017', 8.6],
#  ['Moko Jumbie', '2017', 8.6],
#  ['On the Rocks', '2017', 8.6],
#  ['For Izzy', '2018', 8.6],
#  ['I Did Her Wrong', '2016', 8.6],
#  ['Ann', '2016', 8.6],
#  ['The Man from Ruin', '2016', 8.6],
#  ['Get Big', '2017', 8.6],
#  ['Finding St. Isabel', '2016', 8.6],
#  ['The Home Invaders', '2016', 8.6],
#  ['Honor Amongst Men', '2018', 8.6],
#  ['Battle Fields', '2018', 8.6],
#  ['Ruth: A Faithful Journey', '2017', 8.6],
#  ['Ultra Low', '2018', 8.6],
#  ['Scenes from a Marriage', '1974', 8.6],
#  ['The Stage', '2018', 8.6],
#  ['Roxana', '2018', 8.6],
#  ["Let's Have an Adventure", '2017', 8.6],
#  ['Cidade do Aço', '2017', 8.6],
#  ['The Cossack Whip', '1916', 8.5],
#  ['April Folly', '1920', 8.5],
#  ['City Lights', '1931', 8.5],
#  ['Modern Times', '1936', 8.5],
#  ['The Great Dictator', '1940', 8.5],
#  ['Casablanca', '1942', 8.5],
#  ['Pather Panchali', '1955', 8.5],
#  ['Le Trou', '1960', 8.5],
#  ['Woman in the Dunes', '1964', 8.5],
#  ['Gentlemen of Fortune', '1971', 8.5],
#  ['Only Old Men Are Going to Battle', '1974', 8.5],
#  ['Apocalypse Now', '1979', 8.5],
#  ['Jaane Bhi Do Yaaro', '1983', 8.5],
#  ['Grave of the Fireflies', '1988', 8.5],
#  ['Cinema Paradiso', '1988', 8.5],
#  ['The Lion King', '1994', 8.5],
#  ['Satantango', '1994', 8.5],
#  ['American History X', '1998', 8.5],
#  ["My Mother's Early Lovers", '1998', 8.5],
#  ['Gladiator', '2000', 8.5],
#  ['Evil Slaughter', '1973', 8.5],
#  ['Coyote', '1997', 8.5],
#  ['The Pianist', '2002', 8.5],
#  ['Warm in the Bud', '1970', 8.5],
#  ['Resin', '2001', 8.5],
#  ['Sexgunsmoney@20', '2002', 8.5],
#  ['Kannathil Muthamittal', '2002', 8.5],
#  ['Mutual Admiration Society', '2002', 8.5],
#  ['The Best of Youth', '2003', 8.5],
#  ['Jesus Freak', '2003', 8.5],
#  ['The Departed', '2006', 8.5],
#  ['The Lizard', '2004', 8.5],
#  ['Broken Arrows', '2007', 8.5],
#  ['Dreamer: The Movie', '2004', 8.5],
#  ['The Final Witness', '2004', 8.5],
#  ['The Prestige', '2006', 8.5],
#  ['A Day in the Life of a 6 Ft. Black Man', '1995', 8.5],
#  ['Closure', '2007', 8.5],
#  ['Placebo', '2008', 8.5],
#  ['Amends to My Life', '2007', 8.5],
#  ['Fate Twisted Simply', '2006', 8.5],
#  ['Lenders Morgan', '2006', 8.5],
#  ['Something Blue', '2009', 8.5],
#  ['The Turkey Alibi', '2007', 8.5],
#  ['Golden Sunset', '2009', 8.5],
#  ["Following the Ninth: In the Footsteps of Beethoven's Final Symphony",
#   '2013',
#   8.5],
#  ['The Ones You Love', '2013', 8.5],
#  ['Tangled Web', '2008', 8.5],
#  ['Someday I Suppose', '2005', 8.5],
#  ['Hope for a Thorn', '2009', 8.5],
#  ["The Vampire's Dance", '2008', 8.5],
#  ['Waiting for Tomorrow', '2007', 8.5],
#  ['Fourhand', '2008', 8.5],
#  ['Sun Dogs', '2009', 8.5],
#  ['Fortune 500 Man', '2012', 8.5],
#  ['God Is D_ad', '2009', 8.5],
#  ['Florence: A Matter Between Detectives', '2015', 8.5],
#  ['Behind the Red Motel Door', '2011', 8.5],
#  ['Stalemate', '2011', 8.5],
#  ['99 Percent Sure', '2011', 8.5],
#  ['The Intouchables', '2011', 8.5],
#  ['Pleasant People', '2011', 8.5],
#  ['Rehearsal', '2011', 8.5],
#  ['Pink Skies', '2011', 8.5],
#  ['Art of Deception', '2018', 8.5],
#  ['Salvage Dream', '2010', 8.5],
#  ['Getting Outer Space', '2010', 8.5],
#  ['The Three Way', '2011', 8.5],
#  ['Come Home Raquel', '2011', 8.5],
#  ['Rough Draft', '2011', 8.5],
#  ['The Southside', '2015', 8.5],
#  ['The Fandango Sisters', '2012', 8.5],
#  ['Shades of Treason', '2012', 8.5],
#  ['Ai Means Love', '2011', 8.5],
#  ['The Magic Hour', '2011', 8.5],
#  ['Addison', '2011', 8.5],
#  ['Thunderstruck', '2011', 8.5],
#  ['Finding Home', '2013', 8.5],
#  ['Saybrook: The Tully Girls', '2011', 8.5],
#  ['Cold, I Am: Ballad of the Bark Eater', '2012', 8.5],
#  ['The Rakugo Movie', '2012', 8.5],
#  ["Nobody's Perfect", '2016', 8.5],
#  ['Love All Humans', '2013', 8.5],
#  ['Flea Market Finish Line', '2012', 8.5],
#  ['The Honey Cooler', '2012', 8.5],
#  ['Dante and Minnie', '2012', 8.5],
#  ['Surrender', '2014', 8.5],
#  ['Whiplash', '2014', 8.5],
#  ['Neptune', '2015', 8.5],
#  ['The Happy Caterpillars', '2012', 8.5],
#  ['The Two Pamelas', '2015', 8.5],
#  ['Constant Angel', '2013', 8.5],
#  ['The Thirteenth Step', '2012', 8.5],
#  ['My Name Is Vivienne', '2014', 8.5],
#  ['Subdued', '2014', 8.5],
#  ['The Girls on Liberty Street', '2013', 8.5],
#  ['The Audience', '2013', 8.5],
#  ['Noble Fir', '2014', 8.5],
#  ['The Bad Coming Back', '2013', 8.5],
#  ['Playground of the Native Son', '2013', 8.5],
#  ['Medias Res', '2017', 8.5],
#  ['Closet Space: The Movie', '2016', 8.5],
#  ['Funny Fat Guy', '2016', 8.5],
#  ['The Distance Between Us', '2014', 8.5],
#  ['14/88', '2014', 8.5],
#  ['The Sacrifice of Love', '2014', 8.5],
#  ['One Little Pill', '2014', 8.5],
#  ['Aliens of the West', '2014', 8.5],
#  ['Echo Rhyme', '2016', 8.5],
#  ['Cortez', '2017', 8.5],
#  ['The David Whiting Story', '2014', 8.5],
#  ['Stalemate', '2014', 8.5],
#  ['Moments from a Sidewalk', '2016', 8.5],
#  ["Can't Move On", '2014', 8.5],
#  ['Losing Breen', '2017', 8.5],
#  ['Conflict of Interest', '2017', 8.5],
#  ['Waterless', '2015', 8.5],
#  ['Macie on a Good Day', '2014', 8.5],
#  ['Billy Elliot', '2014', 8.5],
#  ['Where Love Found Me', '2016', 8.5],
#  ['Jim Shoe', '2018', 8.5],
#  ['First Shoot the Lawyers', '2016', 8.5],
#  ['Game On', '2018', 8.5],
#  ['Daydream Hotel', '2017', 8.5],
#  ['Runaway Highway', '2017', 8.5],
#  ['Back for Good', '2017', 8.5],
#  ['What Jack Built', '2015', 8.5],
#  ['Turnt', '2018', 8.5],
#  ['Collegetown', '2015', 8.5],
#  ['Dangal', '2016', 8.5],
#  ['My Friend Violet', '2016', 8.5],
#  ['Savage', '2017', 8.5],
#  ['June Falling Down', '2016', 8.5],
#  ['Something Wicked Something Wonderful', '2017', 8.5],
#  ["The Hollywouldn'ts", '2016', 8.5],
#  ['The New Roommate', '2017', 8.5],
#  ['Hit Men', '2016', 8.5],
#  ['War of the Limelight', '2016', 8.5],
#  ['Mercury in Retrograde', '2017', 8.5],
#  ['Crisis in the Valley', '2016', 8.5],
#  ['Belong to Us', '2018', 8.5],
#  ['The Wake of Dick Johnson', '2016', 8.5],
#  ['Elsewhere', '2017', 8.5],
#  ['Idemuza', '2017', 8.5],
#  ['September Rayne', '2017', 8.5],
#  ['Rose-Colored', '2016', 8.5],
#  ['Rehabilitation of the Hill', '2018', 8.5],
#  ["Kirtland: America's Sacred Ground", '2017', 8.5],
#  ['Wallflower', '2017', 8.5],
#  ['3 Days on the Cross', '2017', 8.5],
#  ['Capernaum', '2018', 8.5],
#  ['Zerk', '2018', 8.5],
#  ["Cap'n Eri", '1915', 8.4],
#  ['Runaway Romany', '1917', 8.4],
#  ['The Witness for the Defense', '1919', 8.4],
#  ['Furlough on Parole', '1938', 8.4],
#  ['Woman Doctor', '1939', 8.4],
#  ['Sunset Boulevard', '1950', 8.4],
#  ['Sansho the Bailiff', '1954', 8.4],
#  ['Stay Alert', '1956', 8.4],
#  ['Paths of Glory', '1957', 8.4],
#  ['Witness for the Prosecution', '1957', 8.4],
#  ['Macario', '1960', 8.4],
#  ['High and Low', '1963', 8.4],
#  ['Hamlet', '1964', 8.4],
#  ['The Crazy-Quilt', '1966', 8.4],
#  ['Samurai Rebellion', '1967', 8.4],
#  ['War and Peace, Part III: The Year 1812', '1967', 8.4],
#  ['Michael the Brave', '1970', 8.4],
#  ['The Wishing Tree', '1976', 8.4],
#  ['Office Romance', '1977', 8.4],
#  ['The Herd', '1978', 8.4],
#  ['Lion of the Desert', '1980', 8.4],
#  ['The Shining', '1980', 8.4],
#  ['Das Boot', '1981', 8.4],
#  ['Once Upon a Time in America', '1984', 8.4],
#  ['Repentance', '1984', 8.4],
#  ['Bum Rap', '1988', 8.4],
#  ['Painted Desert', '1993', 8.4],
#  ['Braveheart', '1995', 8.4],
#  ['American Beauty', '1999', 8.4],
#  ['Arachveulebrivi gamopena', '1968', 8.4],
#  ["It's Alright Ma, I'm Only Trying", '2000', 8.4],
#  ['West Coast', '2000', 8.4],
#  ['The Village Had No Walls', '1995', 8.4],
#  ['The Migration of the Angel', '2001', 8.4],
#  ['Frozen Stiff', '2002', 8.4],
#  ['Smack', '2001', 8.4],
#  ['Urban Playground', '2002', 8.4],
#  ['Pure', '2004', 8.4],
#  ['The Professional', '2003', 8.4],
#  ['Oldboy', '2003', 8.4],
#  ["Beyond Baklava: The Fairy Tale Story of Sylvia's Baklava", '2007', 8.4],
#  ['In Justice', '2004', 8.4],
#  ['Bench at the Edge', '1998', 8.4],
#  ['Broken Echoes', '2004', 8.4],
#  ['Paradise Road', '1988', 8.4],
#  ["Tom's Wife", '2004', 8.4],
#  ['The Lives of Others', '2006', 8.4],
#  ['The Gentleman Don La Mancha', '2004', 8.4],
#  ['Mattie Fresno and the Holoflux Universe', '2007', 8.4],
#  ['Pulling', '2004', 8.4],
#  ["Gettin' Grown", '2004', 8.4],
#  ['Exquisite Corpse', '2004', 8.4],
#  ['Milk Can', '2005', 8.4],
#  ['Sundowning', '2005', 8.4],
#  ['Sweet Underground', '2004', 8.4],
#  ['Solitude', '2005', 8.4],
#  ['Pain Within', '2007', 8.4],
#  ['On Oak Island', '2006', 8.4],
#  ['Out of the Shadows', '2005', 8.4],
#  ['Valerie & Sid', '2006', 8.4],
#  ['Fragments of Daniela', '2006', 8.4],
#  ['Oklahoma Faded Love', '1998', 8.4],
#  ['Á Colombia', '2006', 8.4],
#  ['The Busker', '2006', 8.4],
#  ['JailCity', '2006', 8.4],
#  ['Like Stars on Earth', '2007', 8.4],
#  ['Positive', '2007', 8.4],
#  ['To See the Moon in the Morning Sky', '2007', 8.4],
#  ['Undoing Time', '2008', 8.4],
#  ['Shadowman', '2009', 8.4],
#  ['3 Idiots', '2009', 8.4],
#  ['The Sunset Sky', '2009', 8.4],
#  ['Anger Has a Secret', '2010', 8.4],
#  ['Decomposed', '2009', 8.4],
#  ['Bullet for Breakfast', '1994', 8.4],
#  ['Hello, My Name Is Charlie', '2009', 8.4],
#  ['Curse of the Lechusa', '2009', 8.4],
#  ['Desert Heat', '2003', 8.4],
#  ['A Voice in the Dark', '2013', 8.4],
#  ['Crit-Sit: 593', '2009', 8.4],
#  ['Faux', '2010', 8.4],
#  ['Decomposing Tony Maslow', '2009', 8.4],
#  ['The Art of Power', '2010', 8.4],
#  ['Rainbows End', '2010', 8.4],
#  ['Fields of November', '2010', 8.4],
#  ['Part Time Fabulous', '2011', 8.4],
#  ['Carmen G', '2012', 8.4],
#  ['Django Unchained', '2012', 8.4],
#  ['Sleep Debt', '2012', 8.4],
#  ['Bloodshedding Love', '2011', 8.4],
#  ['Division', '2011', 8.4],
#  ['Suppress Emotions', '2011', 8.4],
#  ['Driftwood', '1994', 8.4],
#  ['Curiosity Killed the Cat', '2012', 8.4],
#  ['Fight Like a Girl', '2013', 8.4],
#  ['Palace Living', '2013', 8.4],
#  ['She Stoops to Conquer', '2012', 8.4],
#  ['Lofty', '2005', 8.4],
#  ['Bernadette', '2013', 8.4],
#  ['A Variety of Mysteries', '2012', 8.4],
#  ['Family Plan', '2011', 8.4],
#  ['Once Forgotten', '2012', 8.4],
#  ['Behind the Scenes: Escape from Cuba', '2003', 8.4],
#  ['Return to Nowhere', '2013', 8.4],
#  ['Tasmanian Tiger', '2014', 8.4],
#  ['Gully Boy', '2019', 8.4],
#  ['The Red Bowtie', '2012', 8.4],
#  ['Footprints', '2012', 8.4],
#  ['North of South, West of East', '2013', 8.4],
#  ['Sarah', '2013', 8.4],
#  ['Trichster', '2015', 8.4],
#  ['Life Changes Everything: Discover Zac Ryan', '2017', 8.4],
#  ['Purgatorio', '2012', 8.4],
#  ['Lone Prophet', '2013', 8.4],
#  ['Spit', '2014', 8.4],
#  ['Yes, And...', '2014', 8.4],
#  ['Brown Sugar Too Bitter for Me', '2013', 8.4],
#  ['As Far as the Eye Can See', '2013', 8.4],
#  ['Damn Foreigners', '2015', 8.4],
#  ['You or a Loved One', '2014', 8.4],
#  ['Chasing Yesterday', '2015', 8.4],
#  ['Bastards y Diablos', '2015', 8.4],
#  ['The Musician', '2017', 8.4],
#  ['Life Is Boring', '2016', 8.4],
#  ['Redemption', '2013', 8.4],
#  ['Ashes of the Phoenix', '2013', 8.4],
#  ['El Sueño', '2016', 8.4],
#  ['Painting Anna', '2019', 8.4],
#  ['30-Love', '2017', 8.4],
#  ['Four Color Eulogy', '2016', 8.4],
#  ['The Old, Old Story', '2015', 8.4],
#  ["We'll Let You Know", '2015', 8.4],
#  ['Broken Angels', '2017', 8.4],
#  ['Trapped', '2015', 8.4],
#  ['Inside Fighter', '2014', 8.4],
#  ['Vow', '2014', 8.4],
#  ['A Meeting of the Minds', '2016', 8.4],
#  ['Twelfth Night', '2014', 8.4],
#  ['My First Kiss and the People Involved', '2016', 8.4],
#  ["One Night at Dante's", '2014', 8.4],
#  ['Market Value', '2017', 8.4],
#  ['Half of Twenty Two', '2014', 8.4],
#  ["Before 'I Do'", '2016', 8.4],
#  ['Kaakkaa Muttai', '2014', 8.4],
#  ['When the Bough Breaks: A Documentary About Postpartum Depression',
#   '2017',
#   8.4],
#  ['Looking for Muhyiddin', '2014', 8.4],
#  ['Delivery Hour', '2014', 8.4],
#  ['The Problem Y', '2014', 8.4],
#  ['Love in Moreno Valley', '2018', 8.4],
#  ["The Devil's Gold", '2015', 8.4],
#  ['ReRUN', '2018', 8.4],
#  ['Most Likely to Succeed', '2015', 8.4],
#  ['For the Coyotes', '2015', 8.4],
#  ['Fat Chance', '2015', 8.4],
#  ['IMperfect', '2016', 8.4],
#  ['Amigos de Risco', '2007', 8.4],
#  ['Guns and Grams', '2016', 8.4],
#  ['Denounced', '2017', 8.4],
#  ['Loves Park', '2017', 8.4],
#  ['Urutau', '2015', 8.4],
#  ['Fortune Defies Death', '2018', 8.4],
#  ['Blue Line Station', '2016', 8.4],
#  ['Your Name.', '2016', 8.4],
#  ['The Wolf Hour', '2019', 8.4],
#  ['About a Donkey', '2018', 8.4],
#  ['Groove', '2017', 8.4],
#  ["What's in a Name", '2016', 8.4],
#  ['Saints Rest', '2018', 8.4],
#  ['Into the Valli', '2018', 8.4],
#  ['Opposite of Ernest', '2016', 8.4],
#  ['Safar', '2016', 8.4],
#  ['Hunting Lands', '2018', 8.4],
#  ['Laura Gets a Cat', '2017', 8.4],
#  ['Palacios', '2017', 8.4],
#  ['Where the Water Runs', '2018', 8.4],
#  ['Ask for Jane', '2018', 8.4],
#  ['Founding Father', '2017', 8.4],
#  ['Thicker Than Blood', '2017', 8.4],
#  ['Cold Brook', '2018', 8.4],
#  ['Summertime', '2018', 8.4],
#  ['#babynymph', '2016', 8.4],
#  ['K.G.F: Chapter 1', '2018', 8.4],
#  ['My Own Private Hell', '2018', 8.4],
#  ['Elegy of a Crime', '2018', 8.4],
#  ['The King an I', '2018', 8.4],
#  ['Halloween II: The Return Of Michael Myers', '2017', 8.4],
#  ["It's No Laughing Matter", '1915', 8.3],
#  ['The Cinema Murder', '1919', 8.3],
#  ['The Kid', '1921', 8.3],
#  ['Janice Meredith', '1924', 8.3],
#  ['Lights of Old Broadway', '1925', 8.3],
#  ['Zander the Great', '1925', 8.3],
#  ['Metropolis', '1927', 8.3],
#  ['The Cameraman', '1928', 8.3],
#  ['The Wind', '1928', 8.3],
#  ['Citizen Kane', '1941', 8.3],
#  ['The Pittsburgh Kid', '1941', 8.3],
#  ['Double Indemnity', '1944', 8.3],
#  ['Children of Paradise', '1945', 8.3],
#  ['Bicycle Thieves', '1948', 8.3],
#  ['The Red Shoes', '1948', 8.3],
#  ['Late Spring', '1949', 8.3],
#  ['All About Eve', '1950', 8.3],
#  ['The Young and the Damned', '1950', 8.3],
#  ['Rashomon', '1950', 8.3],
#  ['Ikiru', '1952', 8.3],
#  ['Racing Blood', '1954', 8.3],
#  ['The Cranes Are Flying', '1957', 8.3],
#  ['The World of Apu', '1959', 8.3],
#  ['The Great War', '1959', 8.3],
#  ['The Apartment', '1960', 8.3],
#  ['Rocco and His Brothers', '1960', 8.3],
#  ['My Son, the Hero', '1961', 8.3],
#  ['Yojimbo', '1961', 8.3],
#  ['The Naked Island', '1960', 8.3],
#  ['Lawrence of Arabia', '1962', 8.3],
#  ['The Given Word', '1962', 8.3],
#  ['To Kill a Mockingbird', '1962', 8.3],
#  ['The Big City', '1963', 8.3],
#  ['Forest of the Hanged', '1965', 8.3],
#  ['An Affair of the Skin', '1963', 8.3],
#  ['Red Beard', '1965', 8.3],
#  ['War and Peace, Part I: Andrei Bolkonsky', '1965', 8.3],
#  ['Nayak: The Hero', '1966', 8.3],
#  ['War and Peace, Part IV: Pierre Bezukhov', '1967', 8.3],
#  ['King Lear', '1971', 8.3],
#  ['A Clockwork Orange', '1971', 8.3],
#  ['The Dawns Here Are Quiet', '1972', 8.3],
#  ['The Sting', '1973', 8.3],
#  ['Dersu Uzala', '1975', 8.3],
#  ['Orderers', '1974', 8.3],
#  ['Taxi Driver', '1976', 8.3],
#  ['The Ascent', '1977', 8.3],
#  ['Autumn Sonata', '1978', 8.3],
#  ['Scarface', '1983', 8.3],
#  ['Amadeus', '1984', 8.3],
#  ['Full Metal Jacket', '1987', 8.3],
#  ['A Short Film About Love', '1988', 8.3],
#  ['Hoop Dreams', '1994', 8.3],
#  ['To Live', '1994', 8.3],
#  ...]

# %%
for k,v in tmp.items():
    print(k, random.sample(v[:100],1))
# Out:
# Romance [['Tarot: A Documentary Love Story', '2014', 8.6]]
# Drama [['GRRF: The Sound of Suicide Postponement', '2009', 9.2]]
# Adventure [['The Lord of the Rings: The Return of the King', '2003', 8.9]]
# Fantasy [['Life of the Party: Vol. II', '2010', 8.6]]
# Biography [['Hell or High Water: The Story of the Nashville Rollergirls', '2012', 8.9]]
# History [['Orderers', '1974', 8.3]]
# War [['Fuel', '2008', 8.1]]
# Comedy [['The Soul Agency', '2009', 9.4]]
# Crime [['Pulse of the Indigo', '2012', 8.5]]
# Mystery [['Prisoners', '2013', 8.1]]
# Horror [['Demons', '1971', 8.2]]
# Thriller [['Hunting Lands', '2018', 8.4]]
# Western [['Howlers', '2018', 8.1]]
# Music [['The Singing Revolution', '2006', 8.4]]
# Action [['Black Beauty Breed', '2014', 9.2]]
# Family [['The Pinchcliffe Grand Prix', '1975', 8.4]]
# Sci-Fi [['An Addicting Picture', '2017', 8.2]]
# Sport [['Rise of the Sufferfests', '2016', 8.0]]
# Documentary [['50 Yard Dash', '2016', 9.3]]
# Musical [['The Courtyard of the Ballads', '1942', 7.8]]
# Film-Noir [['The Killers', '1946', 7.8]]
# Animation [['Max Steel: Team Turbo', '2016', 8.0]]
# News [['The Human Face of Big Data', '2014', 7.2]]
# Adult [['The Treasure Box', '1979', 7.6]]
# Talk-Show [['Revenge of the Motorcycle Mama', '1972', 6.8]]
# Short [['The Fire Island Kids', '1971', 6.7]]
# Reality-TV [['Foreigners out! Schlingensiefs Container', '2002', 7.9]]
# Game-Show [["Wait Wait Don't Tell Me Live!", '2013', 9.0]]
